# %%
import os
os.chdir('/content/drive/MyDrive/research/power system/power_system_centralized_704')

# %%
import numpy as np
from torch.distributions import Categorical, Normal

from memory import Memory
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from util import *
from copy import deepcopy

# %%
def fanin_init(size, fanin=None):
    fanin = fanin or size[0]
    v = 1. / np.sqrt(fanin)
    return torch.Tensor(size).uniform_(-v, v)
class Actor(nn.Module):
    def __init__(self, nb_states, nb_actions, hidden1=128, hidden2=128, init_w=3e-3):
        super(Actor, self).__init__()
        #self.constraints = constraints
        self.nb_actions = nb_actions
        self.fc1 = nn.Linear(nb_states, hidden1)
        #self.fc2 = nn.Linear(hidden1, hidden2)
        self.mu_layer = nn.Linear(hidden1,nb_actions) #mean
        self.sigma_layer = nn.Linear(hidden1,nb_actions)# variance
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self.softplus = nn.Softplus()
        self.sigmoid = nn.Sigmoid()
        self.init_weights(init_w)
        #self.fc = nn.Linear(nb_states,nb_actions)
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        #self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.mu_layer.weight.data.uniform_(-init_w, init_w)
        self.sigma_layer.weight.data.uniform_(-init_w, init_w)
    def forward(self,x):
        out = self.fc1(x)
        out = self.relu(out)
        #out = self.fc2(out)
        #out = self.relu(out)
        mu = self.mu_layer(out)
        sigma = self.sigma_layer(out)
        #out = self.fc3(out)
        #out = self.fc(x)
        mu = self.tanh(mu)#[-1,1]
        sigma = self.softplus(sigma)+ 0.001
        return mu,sigma
    def select_action(self,x):
        mu,sigma_sq = self.forward(x)
        mu = mu.squeeze(0)
        sigma_sq = sigma_sq.squeeze(0)
        #mu = to_numpy(mu)
        #sigma_sq = to_numpy(sigma_sq)
        sigma = torch.sqrt(sigma_sq)
        action = to_tensor(np.random.normal(size = (self.nb_actions,)))
        action = mu + sigma*action
        action = torch.maximum(torch.minimum(torch.tensor(1.0),action),torch.tensor(-1.0))
        prob = 1/torch.sqrt(2*torch.pi*sigma_sq)*torch.exp(-torch.square(action-mu)/(2.0*sigma_sq))
        log_prob = torch.log(prob).sum()
        action = to_numpy(action)
        return action,log_prob
class Critic(nn.Module):
    def __init__(self,nb_states,nb_actions,hidden1 = 128,hidden2 = 128,init_w = 3e-3):
        super(Critic, self).__init__()
       # self.constraints = constraints
        self.fc1 = nn.Linear(nb_states, hidden1)
        #self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden1, 1) 
        self.relu = nn.ReLU()
        self.init_weights(init_w)
        #self.fc = nn.Linear(nb_states+nb_actions,1)
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        #self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    def forward(self,x):
        out = self.fc1(x)
        out = self.relu(out)
        #out = self.fc2(out)
        #out = self.relu(out)
        out = self.fc3(out)
        #out = self.fc(x)
        return out

# %%
criterion = nn.MSELoss()
class AC(object):
    def __init__(self, nb_interval,nb_states,nb_actions, constraints, args):
        if args.seed > 0:
            self.seed(args.seed)
        self.constraints = constraints
        self.nb_interval = nb_interval
        self.nb_states = nb_states
        self.nb_actions = nb_actions
        assert self.nb_states.shape[0] == self.nb_interval
        # Create Actor and Critic Network
        net_cfg = {
            'hidden1':args.hidden1, 
            'hidden2':args.hidden2, 
            'init_w':args.init_w
        }

        self.actor_dict = dict()

        self.actor_optim_dict = dict()

        self.critic_dict = dict()

        self.critic_optim_dict = dict()

        #self.memory_dict = dict()

        for i in range(self.nb_interval):

            self.actor_dict[i] = Actor(self.nb_states[i],self.nb_actions, **net_cfg)

            self.actor_optim_dict[i] = Adam(self.actor_dict[i].parameters(), lr=args.prate)
            

            self.critic_dict[i] = Critic(self.nb_states[i], self.nb_actions, **net_cfg)
            self.critic_optim_dict[i] = Adam(self.critic_dict[i].parameters(), lr=args.rate)



            
            #Create replay buffer
            #self.memory_dict[i] = Memory(limit=args.rmsize)


        #self.random_process = OrnsteinUhlenbeckProcess(size=nb_actions, theta=args.ou_theta, mu=args.ou_mu, sigma=args.ou_sigma)

        # Hyper-parameters
        self.batch_size = args.bsize
        self.tau = args.tau
        self.discount = args.discount


        # 

        self.s_t = None # Most recent state
        self.a_t = None # Most recent action
        self.is_training = True

        # 
        if USE_CUDA: self.cuda()

    def update_policy(self,state,action,log_prob,reward,next_state,time_interval):
        #============Update Critic======================
        value = self.critic_dict[time_interval](to_tensor(np.array([state])))
        with torch.no_grad():
          if time_interval == self.nb_interval -1:
            target = torch.tensor(np.array([reward.astype(np.float32)])).unsqueeze(0).cuda()
          else:
            target = self.critic_dict[time_interval+1](to_tensor(np.array([next_state]))) + reward
          advantage = target - value
        self.critic_dict[time_interval].zero_grad()
        try:
          loss_critic = criterion(target,value)
        except TypeError:
          print(type(value))
          print(type(target))
        loss_critic.backward()
        self.critic_optim_dict[time_interval].step()

        #==============Update Actor==================
        self.actor_dict[time_interval].zero_grad()
        loss_actor = -advantage*log_prob
        loss_actor.backward()
        self.actor_optim_dict[time_interval].step()

        

    def cuda(self):
        for i in range(self.nb_interval):
            self.actor_dict[i].cuda()
            self.critic_dict[i].cuda()



    def select_action(self, s_t,time_interval):
        action,log_prob = self.actor_dict[time_interval].select_action(to_tensor(np.array([s_t])))     
        return action,log_prob

    def seed(self,s):
        torch.manual_seed(s)
        if USE_CUDA:
            torch.cuda.manual_seed(s)
    def initial_memory(self):
      for i in range(self.nb_interval):
        self.memory_dict[i] = Memory(limit=args.rmsize)

# %%
def rescale_action(action,lb,ub):
    return action * (ub- lb) / 2.0 +\
            (lb + ub) / 2.0
class EnvironmentNode1(object):
    def __init__(self, constraints,cost_func,load,nb_interval,gaussian_noise):
        self.constraints = constraints
        self.cost_func = cost_func
        self.load = load
        self.nb_interval = nb_interval
        self.gaussian_noise = gaussian_noise
        self.normal_scale = constraints['normal_scale']
        self.reset()
    def reset(self):
        self.battery = 0.0
        self.observation =  np.array([self.battery*self.constraints['battery_scale'],\
            self.load[0]*self.constraints['load_scale']])
        self.state = np.array([self.battery,\
            self.load[0]])
        self.time_interval = 0
    def get_obs(self):
        return self.observation,self.time_interval
    def reward(self,state,true_action,time_interval):
        if type(time_interval) != int:
            print(time_interval) 
        a_p,a_c= true_action
        
        prod_cost = self.cost_func(a_p)
        """
        chargingMismatchCost = -self.constraints['penaltyCoef']*np.abs(effective_c-a_c)
        productionMismatchCost = -self.constraints['penaltyCoef']*np.abs(effective_p-a_p)
        penalty = chargingMismatchCost + productionMismatchCost
        """
        return prod_cost
    def make_action(self,action,t = None):
        if t is None:
            t = self.time_interval
        a_c = action.item() #production, node 1 charging
        load_t = self.load[t]
        if self.gaussian_noise:
            a_c += np.random.normal(scale = self.normal_scale) 
            a_c = np.clip(a_c,-1,1)


        a_c = rescale_action(a_c,-self.constraints['max_charge'],self.constraints['max_charge'])
              
        
        lb_c = np.maximum(-self.battery,-load_t)
        ub_c = np.minimum(self.constraints['max_energy']-self.battery, self.constraints['max_prod']-load_t)
        
        effective_c = np.minimum(np.maximum(a_c,lb_c),ub_c)

        a_p = effective_c + load_t

        #effective_p = np.minimum(np.maximum(a_p,0.0),self.constraints['max_prod'])

        return np.array([a_p,effective_c])
    def scale_decay(self):
        self.normal_scale *= self.constraints['decay_rate']
    def step(self,action):
        action_copy = deepcopy(action)
        true_action = self.make_action(action)
        costProduction = self.reward(self.state,true_action,self.time_interval)
        costProduction*= self.constraints['reward_scale']
        #violationPenalty*= self.constraints['reward_scale']
        if self.time_interval == self.nb_interval -1:
            self.reset()
            return self.observation,costProduction,action_copy,self.time_interval
        else:
            a_p,a_c = true_action
            self.battery+= a_c
            self.time_interval += 1

            self.state = np.array([self.battery,self.load[self.time_interval]])

            self.observation =  np.array([self.battery*self.constraints['battery_scale'],\
                self.load[self.time_interval]*self.constraints['load_scale']])
            
            return self.observation,costProduction,action_copy,self.time_interval

# %%
class EnvironmentNode2(object):
    def __init__(self, constraints,elFunc,nodalPrice,nb_interval,gaussian_noise):
        self.constraints = constraints
        self.elFunc = elFunc
        self.nodalPrice = nodalPrice
        self.nb_interval = nb_interval
        self.gaussian_noise = gaussian_noise
        self.normal_scale = constraints['normal_scale']
        self.impedance = 0.001
        self.reset()
    def reset(self):
        self.battery = 0.0
        self.observation =  np.array([self.battery*self.constraints['battery_scale'],\
            self.nodalPrice[0]*self.constraints['mc_scale']])
        self.state = np.array([self.battery,\
            self.nodalPrice[0]])
        self.time_interval = 0
    def get_obs(self):
        return self.observation,self.time_interval
    def reward(self,state,true_action,time_interval):
        if type(time_interval) != int:
            print(time_interval) 
        a_t,a_c,a_el = true_action
        
        elUtility = self.elFunc(a_el)
        
        transmission_fee = self.nodalPrice[time_interval]*a_t

        
        return elUtility, transmission_fee
    def make_action(self,action,t = None):
        if t is None:
            t = self.time_interval
        a_t,a_c = action #transmission,charging,elastic load
        
        if self.gaussian_noise:
            a_t += np.random.normal(scale = self.normal_scale) 
            a_t = np.clip(a_t,-1,1)
            a_c += np.random.normal(scale = self.normal_scale) 
            a_c = np.clip(a_c,-1,1)

        
        max_trans = self.constraints['max_angle']/self.impedance
        
        a_t = rescale_action(a_t,lb = 0.0, ub= max_trans)
        a_c = rescale_action(a_c,lb = -self.constraints['max_charge'],ub = self.constraints['max_charge'])
        
     
        lb_c = -self.battery
        ub_c = np.minimum(self.constraints['max_energy']-self.battery, a_t)
        
        effective_c = np.minimum(np.maximum(a_c,lb_c),ub_c)

        a_el = a_t - effective_c

        return np.array([a_t,effective_c,a_el])
    def scale_decay(self):
        self.normal_scale *= self.constraints['decay_rate']
    def step(self,action):
        action_copy = deepcopy(action)
        true_action = self.make_action(action)
        elUtility,transmission_fee = self.reward(self.state,true_action,self.time_interval)
        elUtility*= self.constraints['reward_scale']
        transmission_fee*= self.constraints['reward_scale']
        if self.time_interval == self.nb_interval -1:
            self.reset()
            return self.observation,elUtility,transmission_fee,action_copy,self.time_interval
        else:
            a_t,a_c,a_el = true_action
            self.battery+= a_c
            self.time_interval += 1

            self.state = np.array([self.battery,self.nodalPrice[self.time_interval]])

            self.observation =  np.array([self.battery*self.constraints['battery_scale'],\
                self.nodalPrice[self.time_interval]*self.constraints['mc_scale']])
            
            return self.observation,elUtility,transmission_fee,action_copy,self.time_interval

# %%
def trainingNode1():
  step = 0
  observation,time_interval = envNode1.get_obs()
  while step < args.train_iter:
    action,log_prob = agent1.select_action(observation,time_interval)
    new_observation,cP,action,new_time_interval = envNode1.step(action)
    agent1.update_policy(observation,action,log_prob,cP,new_observation,time_interval)
    observation = new_observation
    time_interval = new_time_interval
    step += 1

# %%
def trainingNode2():
  step = 0
  observation,time_interval = envNode2.get_obs()
  while step < args.train_iter:
    action,log_prob = agent2.select_action(observation,time_interval)
    new_observation,eLU,tF,action,new_time_interval = envNode2.step(action)
    agent2.update_policy(observation,action,log_prob,eLU+tF,new_observation,time_interval)
    observation = new_observation
    time_interval = new_time_interval
    step += 1

# %%
import logging
import sys
import argparse
import datetime

# %%
constraints = dict()
constraints['max_prod'] = 600
constraints['max_charge'] = 200
constraints['max_energy'] = 280
constraints['max_angle'] = 0.08
constraints['load_scale'] = 0.005
constraints['mc_scale'] = 0.05
constraints['battery_scale'] = 0.01
constraints['reward_scale'] = 0.001
constraints['normal_scale'] = 0.05
constraints['decay_rate'] = 0.99
constraints['penaltyCoef'] = 100.0

# %%
def cost_func(x):
  return -(20+2*x+0.02*x**2)
def elastic_load_func(x):
  return -0.02*x**2 + 12*x +5
def mc_func(x):
  return -0.04*x-2

 
impedance = 0.001
startup = 30
nb_interval = 8
nb_states_1 = np.array([1+1 for x in range(nb_interval)])
nb_states_2 = np.array([1+1 for x in range(nb_interval)])
nb_actions1 = 1
nb_actions2 = 2
load_1 = np.array([100,80,70,75,150,180,220,200]).astype(np.float32)

# %%
parser = argparse.ArgumentParser(description='Power system DDPG')

parser.add_argument('--hidden1', default=128, type=int, help='hidden num of first fully connect layer')
parser.add_argument('--hidden2', default=256, type=int, help='hidden num of second fully connect layer')
parser.add_argument('--rate', default=0.001, type=float, help='learning rate')
parser.add_argument('--actorDecay', default=0.999, type=float, help='gamma for actor optimization schedular')
parser.add_argument('--criticDecay', default=0.9999, type=float, help='gamma for critic optimization schedular')
parser.add_argument('--prate', default=0.0001, type=float, help='policy net learning rate (only for DDPG)')
parser.add_argument('--warmup', default=1500, type=int, help='time without training but only filling the replay memory')
parser.add_argument('--discount', default=1., type=float, help='')
parser.add_argument('--bsize', default=128, type=int, help='minibatch size')
parser.add_argument('--rmsize', default=50000, type=int, help='memory size')
parser.add_argument('--tau', default=0.3, type=float, help='moving average for target network')
parser.add_argument('--init_w', default=0.03, type=float, help='') 
parser.add_argument('--train_iter', default=2000, type=int, help='train iters each timestep')
parser.add_argument('--seed', default=123, type=int, help='')
args = parser.parse_args("")

# %%
np.random.seed(13)

# %%
randomness = False #no gaussian noise if False
agent1 = AC(nb_interval,nb_states_1,nb_actions1, constraints, args)
agent2 = AC(nb_interval,nb_states_2,nb_actions2, constraints, args)

# %%
envNode1 =  EnvironmentNode1(constraints,cost_func,load_1,nb_interval,gaussian_noise = randomness)
envNode2 = EnvironmentNode2(constraints,elastic_load_func,np.zeros(nb_interval),nb_interval,gaussian_noise = randomness)

# %%
#transmissionVolume = np.array([69.27,75.937,79.27,77.604,52.604,42.604,29.27,35.937])
transmissionVolume = np.zeros(nb_interval)
nodalPrice = np.zeros(nb_interval)
#nodalPrice = np.ones(nb_interval)*(-9.68748)

# %%
epoch =0
while epoch < 300:
  #agent1.initial_memory
  #agent2.initial_memory
  envNode1.load = load_1 + transmissionVolume
  envNode2.nodalPrice = nodalPrice
  trainingNode1()
  trainingNode2()
  with torch.no_grad():
    totalUtility = 0.0
    totalReturn = 0.0
    actionNode1_list = []
    actionNode2_list = []
    envNode1.reset()
    envNode2.reset()
    observationNode1,time_interval = envNode1.get_obs()
    observationNode2,_ = envNode2.get_obs()
    for timeStep in range(nb_interval):
      actionNode1,logProbNode1 = agent1.select_action(observationNode1,time_interval)
      actionNode2,logProbNode2 = agent2.select_action(observationNode2,time_interval)
      observationNode1,cP,actionNode1,time_interval = envNode1.step(actionNode1)
      observationNode2,eLU,tF,actionNode2,_ = envNode2.step(actionNode2)
      actionNode1_list.append(actionNode1)
      actionNode2_list.append(actionNode2)
      totalUtility +=  eLU
      totalReturn += cP
    actionNode1_list = np.vstack(actionNode1_list)
    actionNode2_list = np.vstack(actionNode2_list)
    productionArray = rescale_action(actionNode1_list[:,0], 0.0, constraints['max_prod'])
    mcArray = mc_func(productionArray)
    transmissionArray = rescale_action(actionNode2_list[:,0],0.0,constraints['max_angle']/impedance)
    
    nodalPrice = 0.95*nodalPrice + 0.05*mcArray
    transmissionVolume = 0.95*transmissionVolume + 0.05*transmissionArray
    print("=============EPOCH {}===============".format(epoch))
    print("Utility is ",totalUtility)
    print("Cost is ",totalReturn)
    print("nodalPrice discrepancy is ",np.linalg.norm(mcArray-nodalPrice))
    print("transmission discrepancy is ",np.linalg.norm(transmissionArray-transmissionVolume))
  epoch += 1
# Out:
# =============EPOCH 0===============
# Utility is  3.8507830253821522
# Cost is  -8.918429164307526
# nodalPrice discrepancy is  51.440452828225446
# transmission discrepancy is  134.2662103720378
# =============EPOCH 1===============
# Utility is  4.099086187845349
# Cost is  -7.0092988107409635
# nodalPrice discrepancy is  32.15071614544823
# transmission discrepancy is  145.44356556997462
# =============EPOCH 2===============
# Utility is  3.7485421845118556
# Cost is  -5.943706607995619
# nodalPrice discrepancy is  19.836577310730743
# transmission discrepancy is  116.82039810596177
# =============EPOCH 3===============
# Utility is  3.59036062966727
# Cost is  -8.21795896375049
# nodalPrice discrepancy is  27.804915773629954
# transmission discrepancy is  116.02477157408244
# =============EPOCH 4===============
# Utility is  5.656069921035893
# Cost is  -7.157187969531993
# nodalPrice discrepancy is  31.80613287803263
# transmission discrepancy is  161.10803129000777
# =============EPOCH 5===============
# Utility is  4.2651022156030685
# Cost is  -9.712568207081786
# nodalPrice discrepancy is  31.62874408599149
# transmission discrepancy is  121.63399874229144
# =============EPOCH 6===============
# Utility is  5.289658954213559
# Cost is  -6.529961105578013
# nodalPrice discrepancy is  9.399582768716781
# transmission discrepancy is  146.32539203721961
# =============EPOCH 7===============
# Utility is  6.1721902107962485
# Cost is  -9.043447149811618
# nodalPrice discrepancy is  24.110417305784225
# transmission discrepancy is  157.026502609924
# =============EPOCH 8===============
# Utility is  3.980252472571799
# Cost is  -7.148799330342904
# nodalPrice discrepancy is  19.888998231618846
# transmission discrepancy is  100.92646613283864
# =============EPOCH 9===============
# Utility is  4.064278362096049
# Cost is  -6.960813600181703
# nodalPrice discrepancy is  9.852732061584096
# transmission discrepancy is  99.79063589049252
# =============EPOCH 10===============
# Utility is  5.470096385189695
# Cost is  -7.041371049485624
# nodalPrice discrepancy is  18.189121631891773
# transmission discrepancy is  126.12104786331106
# =============EPOCH 11===============
# Utility is  5.974142152402639
# Cost is  -7.1839021128773854
# nodalPrice discrepancy is  10.530100597667301
# transmission discrepancy is  129.82506745411143
# =============EPOCH 12===============
# Utility is  4.824514231557922
# Cost is  -7.34705316696445
# nodalPrice discrepancy is  4.382252485202568
# transmission discrepancy is  106.92525326151568
# =============EPOCH 13===============
# Utility is  5.207170599617156
# Cost is  -7.426208380177715
# nodalPrice discrepancy is  17.54804196421823
# transmission discrepancy is  118.14736450617852
# =============EPOCH 14===============
# Utility is  6.218938033614485
# Cost is  -7.948110853132892
# nodalPrice discrepancy is  23.64462877414929
# transmission discrepancy is  120.93923883320322
# =============EPOCH 15===============
# Utility is  5.4405572113026075
# Cost is  -7.742687371740353
# nodalPrice discrepancy is  10.200397608714498
# transmission discrepancy is  107.55424520490759
# =============EPOCH 16===============
# Utility is  5.649118876777723
# Cost is  -7.86262529033696
# nodalPrice discrepancy is  5.3810418676610805
# transmission discrepancy is  113.7611205053539
# =============EPOCH 17===============
# Utility is  5.364581839501214
# Cost is  -8.007562552774262
# nodalPrice discrepancy is  8.236801404507553
# transmission discrepancy is  88.8791475198703
# =============EPOCH 18===============
# Utility is  5.6915707483354465
# Cost is  -8.044668018999271
# nodalPrice discrepancy is  11.794191920206439
# transmission discrepancy is  91.37779408876351
# =============EPOCH 19===============
# Utility is  5.465609373145693
# Cost is  -8.288437688301102
# nodalPrice discrepancy is  15.5753059648625
# transmission discrepancy is  94.0924774111005
# =============EPOCH 20===============
# Utility is  6.135928233411264
# Cost is  -8.281190664700592
# nodalPrice discrepancy is  16.54220823327848
# transmission discrepancy is  96.41468144076703
# =============EPOCH 21===============
# Utility is  5.335136804081386
# Cost is  -8.396980800126832
# nodalPrice discrepancy is  13.483966302948721
# transmission discrepancy is  76.36865600132965
# =============EPOCH 22===============
# Utility is  6.014281105477311
# Cost is  -8.586130540176075
# nodalPrice discrepancy is  13.952129775361385
# transmission discrepancy is  86.28843988974465
# =============EPOCH 23===============
# Utility is  5.947553798387572
# Cost is  -8.59110775256871
# nodalPrice discrepancy is  8.970860944937167
# transmission discrepancy is  81.46534261664857
# =============EPOCH 24===============
# Utility is  5.677321230065823
# Cost is  -8.691066052994884
# nodalPrice discrepancy is  12.146461483806892
# transmission discrepancy is  64.66820306641164
# =============EPOCH 25===============
# Utility is  5.005908626112987
# Cost is  -8.76874169001993
# nodalPrice discrepancy is  8.373760192091135
# transmission discrepancy is  53.879664567420484
# =============EPOCH 26===============
# Utility is  5.93361364434944
# Cost is  -10.614356307798985
# nodalPrice discrepancy is  22.65832293800271
# transmission discrepancy is  67.64697965242304
# =============EPOCH 27===============
# Utility is  5.353362519528497
# Cost is  -8.880966360957375
# nodalPrice discrepancy is  13.667996658999229
# transmission discrepancy is  51.98048429979998
# =============EPOCH 28===============
# Utility is  5.791943401108107
# Cost is  -8.992346704152961
# nodalPrice discrepancy is  14.565401133657394
# transmission discrepancy is  61.07530551234143
# =============EPOCH 29===============
# Utility is  6.159384890585255
# Cost is  -9.00347351841528
# nodalPrice discrepancy is  13.266183279291921
# transmission discrepancy is  73.31888807414045
# =============EPOCH 30===============
# Utility is  5.839936286256108
# Cost is  -9.096194227620304
# nodalPrice discrepancy is  10.648145952450813
# transmission discrepancy is  63.51441291694847
# =============EPOCH 31===============
# Utility is  5.845135659598737
# Cost is  -9.171326597429614
# nodalPrice discrepancy is  11.646238760821413
# transmission discrepancy is  60.839598327979274
# =============EPOCH 32===============
# Utility is  5.414036616441667
# Cost is  -9.236123685804813
# nodalPrice discrepancy is  6.616031181893446
# transmission discrepancy is  65.56690728630939
# =============EPOCH 33===============
# Utility is  5.677864702938558
# Cost is  -9.287192206003906
# nodalPrice discrepancy is  13.373065399736408
# transmission discrepancy is  52.752927997453504
# =============EPOCH 34===============
# Utility is  5.537483112024927
# Cost is  -9.350157220959236
# nodalPrice discrepancy is  11.970500238141982
# transmission discrepancy is  56.479580702306784
# =============EPOCH 35===============
# Utility is  6.023774829404547
# Cost is  -9.400727442626234
# nodalPrice discrepancy is  8.170145568267914
# transmission discrepancy is  49.30095422258341
# =============EPOCH 36===============
# Utility is  6.370713195902965
# Cost is  -9.465167956141114
# nodalPrice discrepancy is  7.134333070054463
# transmission discrepancy is  59.33447015299669
# =============EPOCH 37===============
# Utility is  5.804349391536667
# Cost is  -9.55609350845002
# nodalPrice discrepancy is  15.453512340814262
# transmission discrepancy is  47.12457102975342
# =============EPOCH 38===============
# Utility is  5.1785260030811395
# Cost is  -9.598869502850345
# nodalPrice discrepancy is  10.757200443242342
# transmission discrepancy is  56.61118772771488
# =============EPOCH 39===============
# Utility is  6.086973620909714
# Cost is  -10.042442586144945
# nodalPrice discrepancy is  13.978597009128343
# transmission discrepancy is  56.70586263143729
# =============EPOCH 40===============
# Utility is  6.589392860834309
# Cost is  -9.659982950124226
# nodalPrice discrepancy is  7.735884758696712
# transmission discrepancy is  56.45614853173424
# =============EPOCH 41===============
# Utility is  6.088568265124781
# Cost is  -9.74722271807708
# nodalPrice discrepancy is  11.598684830979339
# transmission discrepancy is  51.61433649996401
# =============EPOCH 42===============
# Utility is  5.352956552434836
# Cost is  -9.798599048170967
# nodalPrice discrepancy is  6.687170514802821
# transmission discrepancy is  40.83656602050233
# =============EPOCH 43===============
# Utility is  6.124437874273419
# Cost is  -9.805901793805816
# nodalPrice discrepancy is  8.504945329981291
# transmission discrepancy is  39.114071054257074
# =============EPOCH 44===============
# Utility is  5.124225703142844
# Cost is  -10.131753462931599
# nodalPrice discrepancy is  16.206531138334043
# transmission discrepancy is  55.25108344278588
# =============EPOCH 45===============
# Utility is  5.840265251088454
# Cost is  -9.848721759962709
# nodalPrice discrepancy is  7.199235262159139
# transmission discrepancy is  41.372635265359314
# =============EPOCH 46===============
# Utility is  5.581485021824478
# Cost is  -9.884435433178664
# nodalPrice discrepancy is  11.52079152823044
# transmission discrepancy is  48.66242664314502
# =============EPOCH 47===============
# Utility is  5.259966410308456
# Cost is  -9.898552828265347
# nodalPrice discrepancy is  11.811686437296348
# transmission discrepancy is  36.25419374433257
# =============EPOCH 48===============
# Utility is  6.113182756512924
# Cost is  -9.900257185770423
# nodalPrice discrepancy is  8.733248554664957
# transmission discrepancy is  43.869193142680416
# =============EPOCH 49===============
# Utility is  6.105423004395636
# Cost is  -10.029778435758706
# nodalPrice discrepancy is  15.483693581580992
# transmission discrepancy is  41.46120745928883
# =============EPOCH 50===============
# Utility is  6.114456450241667
# Cost is  -9.996662068495645
# nodalPrice discrepancy is  10.387075286995332
# transmission discrepancy is  36.20304468236561
# =============EPOCH 51===============
# Utility is  5.703188130149451
# Cost is  -10.038462750669536
# nodalPrice discrepancy is  9.441358997205
# transmission discrepancy is  48.676782740794664
# =============EPOCH 52===============
# Utility is  5.7006342107267
# Cost is  -10.048080763450871
# nodalPrice discrepancy is  10.715257578408588
# transmission discrepancy is  36.789103781965906
# =============EPOCH 53===============
# Utility is  5.647718973972808
# Cost is  -10.246170851160983
# nodalPrice discrepancy is  15.261974292578804
# transmission discrepancy is  38.693685315976765
# =============EPOCH 54===============
# Utility is  5.856510213981683
# Cost is  -10.084195218040232
# nodalPrice discrepancy is  11.816869593958955
# transmission discrepancy is  40.0073059754277
# =============EPOCH 55===============
# Utility is  5.304865520622563
# Cost is  -10.36180563888113
# nodalPrice discrepancy is  14.386846224445687
# transmission discrepancy is  39.07520131283282
# =============EPOCH 56===============
# Utility is  4.9904446846992565
# Cost is  -10.12651238472568
# nodalPrice discrepancy is  12.179877983095608
# transmission discrepancy is  57.73455038215575
# =============EPOCH 57===============
# Utility is  6.206105872815674
# Cost is  -10.182456405422812
# nodalPrice discrepancy is  12.530693732054294
# transmission discrepancy is  38.761821219584
# =============EPOCH 58===============
# Utility is  6.2240107039681085
# Cost is  -10.147767018282018
# nodalPrice discrepancy is  6.666961441622327
# transmission discrepancy is  41.16555144957904
# =============EPOCH 59===============
# Utility is  6.228224137471272
# Cost is  -10.15248770939739
# nodalPrice discrepancy is  15.684170492223712
# transmission discrepancy is  37.0830802435359
# =============EPOCH 60===============
# Utility is  6.3400282753986215
# Cost is  -10.222805448155462
# nodalPrice discrepancy is  8.130272369725727
# transmission discrepancy is  33.6044109527063
# =============EPOCH 61===============
# Utility is  6.651330048105649
# Cost is  -10.279778191741851
# nodalPrice discrepancy is  13.1962468845191
# transmission discrepancy is  38.00161721532213
# =============EPOCH 62===============
# Utility is  4.867444663827035
# Cost is  -10.317327435691055
# nodalPrice discrepancy is  11.252342080829857
# transmission discrepancy is  53.685540238998314
# =============EPOCH 63===============
# Utility is  6.363227856814567
# Cost is  -10.273711859339567
# nodalPrice discrepancy is  8.296382078568564
# transmission discrepancy is  33.61014546907368
# =============EPOCH 64===============
# Utility is  6.410589418171403
# Cost is  -10.313178000837414
# nodalPrice discrepancy is  12.770769328002832
# transmission discrepancy is  31.529974744468905
# =============EPOCH 65===============
# Utility is  6.286405960972185
# Cost is  -10.347938523917943
# nodalPrice discrepancy is  10.508983511956265
# transmission discrepancy is  29.188150518008726
# =============EPOCH 66===============
# Utility is  6.353412583642533
# Cost is  -10.371822738687435
# nodalPrice discrepancy is  14.857131823235445
# transmission discrepancy is  29.854781714244286
# =============EPOCH 67===============
# Utility is  6.145097839056589
# Cost is  -10.416912196702212
# nodalPrice discrepancy is  17.630212086163837
# transmission discrepancy is  33.583086417546085
# =============EPOCH 68===============
# Utility is  5.740086992195088
# Cost is  -10.423958091605256
# nodalPrice discrepancy is  12.96619250309624
# transmission discrepancy is  34.15226990834191
# =============EPOCH 69===============
# Utility is  6.017951712087723
# Cost is  -10.43966749716182
# nodalPrice discrepancy is  8.168598472911324
# transmission discrepancy is  36.690498199133536
# =============EPOCH 70===============
# Utility is  5.998442592746986
# Cost is  -10.448834566150362
# nodalPrice discrepancy is  9.076800029141705
# transmission discrepancy is  39.59790476045076
# =============EPOCH 71===============
# Utility is  5.767126583558109
# Cost is  -10.498850688117397
# nodalPrice discrepancy is  16.57179487570711
# transmission discrepancy is  36.50887539838236
# =============EPOCH 72===============
# Utility is  6.341247830721635
# Cost is  -10.464300822427028
# nodalPrice discrepancy is  7.404844556215113
# transmission discrepancy is  26.4659277700053
# =============EPOCH 73===============
# Utility is  5.961714160076946
# Cost is  -10.56932230594983
# nodalPrice discrepancy is  12.818673106546722
# transmission discrepancy is  33.59865066814666
# =============EPOCH 74===============
# Utility is  6.045541695335597
# Cost is  -10.497251323368886
# nodalPrice discrepancy is  7.629857477648091
# transmission discrepancy is  27.341883799082254
# =============EPOCH 75===============
# Utility is  6.482396896037608
# Cost is  -10.509693897686969
# nodalPrice discrepancy is  8.688197716920996
# transmission discrepancy is  30.81401846422731
# =============EPOCH 76===============
# Utility is  6.357307881411964
# Cost is  -10.540559953901896
# nodalPrice discrepancy is  8.348131226605798
# transmission discrepancy is  28.106774119845195
# =============EPOCH 77===============
# Utility is  6.26322836946006
# Cost is  -10.570507720370045
# nodalPrice discrepancy is  7.25045899102005
# transmission discrepancy is  25.18572941600752
# =============EPOCH 78===============
# Utility is  6.424749247553404
# Cost is  -10.594774539122149
# nodalPrice discrepancy is  11.852268594149402
# transmission discrepancy is  25.202601386771686
# =============EPOCH 79===============
# Utility is  6.361455839668695
# Cost is  -10.618438979258968
# nodalPrice discrepancy is  10.164869877289647
# transmission discrepancy is  23.486753301782702
# =============EPOCH 80===============
# Utility is  6.28841263115649
# Cost is  -11.130290833404674
# nodalPrice discrepancy is  17.946404838512326
# transmission discrepancy is  27.056162293736953
# =============EPOCH 81===============
# Utility is  6.0623161023608105
# Cost is  -10.66115017269827
# nodalPrice discrepancy is  7.447691407895718
# transmission discrepancy is  29.545253419813655
# =============EPOCH 82===============
# Utility is  5.9063075606889335
# Cost is  -11.717675133270493
# nodalPrice discrepancy is  19.2928765094432
# transmission discrepancy is  27.924724492435242
# =============EPOCH 83===============
# Utility is  5.928617228559647
# Cost is  -11.65685273513721
# nodalPrice discrepancy is  18.198692399802066
# transmission discrepancy is  41.569752478395436
# =============EPOCH 84===============
# Utility is  6.157133466769698
# Cost is  -10.60114157419208
# nodalPrice discrepancy is  13.826589792848768
# transmission discrepancy is  24.229267538305777
# =============EPOCH 85===============
# Utility is  5.831402985389772
# Cost is  -10.67690468850044
# nodalPrice discrepancy is  11.160911402805523
# transmission discrepancy is  33.75895785239605
# =============EPOCH 86===============
# Utility is  6.45495664485294
# Cost is  -11.629078886478009
# nodalPrice discrepancy is  17.91581533199747
# transmission discrepancy is  25.10977283038651
# =============EPOCH 87===============
# Utility is  6.059426321844102
# Cost is  -10.694155521512291
# nodalPrice discrepancy is  8.28201633839196
# transmission discrepancy is  25.03806204673539
# =============EPOCH 88===============
# Utility is  6.4744415257861
# Cost is  -10.693945473789356
# nodalPrice discrepancy is  8.670867524005748
# transmission discrepancy is  23.760778967626663
# =============EPOCH 89===============
# Utility is  5.877145403352181
# Cost is  -10.715519755400091
# nodalPrice discrepancy is  7.117368535216931
# transmission discrepancy is  29.712296097915374
# =============EPOCH 90===============
# Utility is  6.196888458404279
# Cost is  -10.708732813981772
# nodalPrice discrepancy is  11.55222731871738
# transmission discrepancy is  39.98652494547934
# =============EPOCH 91===============
# Utility is  5.396149082446089
# Cost is  -10.717680941584678
# nodalPrice discrepancy is  9.930749355724872
# transmission discrepancy is  56.142789518733714
# =============EPOCH 92===============
# Utility is  5.982192952648124
# Cost is  -10.696937559112165
# nodalPrice discrepancy is  7.895106799678328
# transmission discrepancy is  25.424109899049395
# =============EPOCH 93===============
# Utility is  6.527600593118512
# Cost is  -10.667627018746876
# nodalPrice discrepancy is  16.18651746547103
# transmission discrepancy is  21.196889068168545
# =============EPOCH 94===============
# Utility is  5.810550386762035
# Cost is  -10.730377561462683
# nodalPrice discrepancy is  9.140160742666918
# transmission discrepancy is  29.650807726077154
# =============EPOCH 95===============
# Utility is  6.378101005161299
# Cost is  -10.715640204552107
# nodalPrice discrepancy is  8.597253926522
# transmission discrepancy is  21.75222627674062
# =============EPOCH 96===============
# Utility is  6.116756695771118
# Cost is  -10.735681894029087
# nodalPrice discrepancy is  6.993283169911394
# transmission discrepancy is  26.202390070064336
# =============EPOCH 97===============
# Utility is  6.3183990625661295
# Cost is  -10.737661113054934
# nodalPrice discrepancy is  5.945877427302565
# transmission discrepancy is  24.41605399301604
# =============EPOCH 98===============
# Utility is  6.564903742324791
# Cost is  -10.755078455687437
# nodalPrice discrepancy is  12.089887754811624
# transmission discrepancy is  23.91944068958907
# =============EPOCH 99===============
# Utility is  6.099647987197237
# Cost is  -10.780335221726094
# nodalPrice discrepancy is  9.068119553388113
# transmission discrepancy is  26.388262046701033
# =============EPOCH 100===============
# Utility is  6.115672599382462
# Cost is  -10.773020314147082
# nodalPrice discrepancy is  9.434372951446933
# transmission discrepancy is  19.285153112619913
# =============EPOCH 101===============
# Utility is  6.22418370911099
# Cost is  -10.771081447883839
# nodalPrice discrepancy is  9.263530104530783
# transmission discrepancy is  25.8826421485722
# =============EPOCH 102===============
# Utility is  6.552912635591752
# Cost is  -10.780401669571546
# nodalPrice discrepancy is  14.429839680084527
# transmission discrepancy is  19.589395227819352
# =============EPOCH 103===============
# Utility is  6.604097072930595
# Cost is  -10.849663554200543
# nodalPrice discrepancy is  14.483505519012837
# transmission discrepancy is  18.1058675462595
# =============EPOCH 104===============
# Utility is  6.105322302784248
# Cost is  -10.827174640088375
# nodalPrice discrepancy is  11.893481277186325
# transmission discrepancy is  32.02100729814079
# =============EPOCH 105===============
# Utility is  6.606118094820561
# Cost is  -10.86512058979823
# nodalPrice discrepancy is  16.850554980265784
# transmission discrepancy is  17.670006623261028
# =============EPOCH 106===============
# Utility is  6.481028192842549
# Cost is  -12.223535429774145
# nodalPrice discrepancy is  21.73656401993061
# transmission discrepancy is  21.008261257216173
# =============EPOCH 107===============
# Utility is  5.792683626357824
# Cost is  -10.87737908747269
# nodalPrice discrepancy is  9.765059599600752
# transmission discrepancy is  30.74145783882642
# =============EPOCH 108===============
# Utility is  5.929064926990919
# Cost is  -11.441841289916383
# nodalPrice discrepancy is  15.591664940326103
# transmission discrepancy is  31.350457955741916
# =============EPOCH 109===============
# Utility is  6.190660057341823
# Cost is  -10.845094438377604
# nodalPrice discrepancy is  11.936668587214461
# transmission discrepancy is  31.129612173766436
# =============EPOCH 110===============
# Utility is  6.577368444690852
# Cost is  -10.86533351746165
# nodalPrice discrepancy is  9.81567175795669
# transmission discrepancy is  18.08747572156101
# =============EPOCH 111===============
# Utility is  6.298492331393918
# Cost is  -10.887931395952858
# nodalPrice discrepancy is  6.99839080563931
# transmission discrepancy is  15.395004375450483
# =============EPOCH 112===============
# Utility is  6.384079583918091
# Cost is  -10.894910810452803
# nodalPrice discrepancy is  12.175912816133211
# transmission discrepancy is  23.978374661410264
# =============EPOCH 113===============
# Utility is  6.124522910992162
# Cost is  -10.887212361524007
# nodalPrice discrepancy is  14.430720843562522
# transmission discrepancy is  21.860690844964633
# =============EPOCH 114===============
# Utility is  5.885704741331954
# Cost is  -10.902065906625152
# nodalPrice discrepancy is  8.32470041620043
# transmission discrepancy is  28.69143241901898
# =============EPOCH 115===============
# Utility is  6.048647550770946
# Cost is  -10.883765194972867
# nodalPrice discrepancy is  7.928990069627387
# transmission discrepancy is  34.23598303709217
# =============EPOCH 116===============
# Utility is  6.123164968153382
# Cost is  -10.873334639913608
# nodalPrice discrepancy is  6.867777127903925
# transmission discrepancy is  21.568573298402825
# =============EPOCH 117===============
# Utility is  5.865099982051965
# Cost is  -10.874803575459218
# nodalPrice discrepancy is  10.794894509150241
# transmission discrepancy is  37.278126126797375
# =============EPOCH 118===============
# Utility is  6.378522782335966
# Cost is  -11.011061515941927
# nodalPrice discrepancy is  12.487184942550197
# transmission discrepancy is  20.92566776212452
# =============EPOCH 119===============
# Utility is  6.3775075902357825
# Cost is  -10.875410752466836
# nodalPrice discrepancy is  9.995668232830125
# transmission discrepancy is  22.66990826030718
# =============EPOCH 120===============
# Utility is  6.1756001444621305
# Cost is  -10.870319684046637
# nodalPrice discrepancy is  12.089752699422586
# transmission discrepancy is  21.80147703699037
# =============EPOCH 121===============
# Utility is  5.999825413283122
# Cost is  -10.880915698176416
# nodalPrice discrepancy is  12.817417212011415
# transmission discrepancy is  32.88022151505019
# =============EPOCH 122===============
# Utility is  6.235569754620539
# Cost is  -10.874400735819744
# nodalPrice discrepancy is  7.858499936280976
# transmission discrepancy is  25.507142299961682
# =============EPOCH 123===============
# Utility is  5.750448818071835
# Cost is  -10.876250895309006
# nodalPrice discrepancy is  12.157901779104664
# transmission discrepancy is  38.518335437630405
# =============EPOCH 124===============
# Utility is  6.49253761872226
# Cost is  -10.846888288823267
# nodalPrice discrepancy is  8.236226875533042
# transmission discrepancy is  16.736442750441523
# =============EPOCH 125===============
# Utility is  6.214098371466143
# Cost is  -10.867627140864467
# nodalPrice discrepancy is  9.270818577837257
# transmission discrepancy is  28.58732563193546
# =============EPOCH 126===============
# Utility is  6.522732070065228
# Cost is  -11.003115930265693
# nodalPrice discrepancy is  15.111023215667164
# transmission discrepancy is  16.92648286474173
# =============EPOCH 127===============
# Utility is  6.06594034037387
# Cost is  -10.884542149883899
# nodalPrice discrepancy is  8.267874902321847
# transmission discrepancy is  30.335765908961637
# =============EPOCH 128===============
# Utility is  6.2230387105496
# Cost is  -10.875445373692942
# nodalPrice discrepancy is  9.077616628610507
# transmission discrepancy is  16.785776173800443
# =============EPOCH 129===============
# Utility is  6.094548682270492
# Cost is  -10.876712830120661
# nodalPrice discrepancy is  11.976973153560893
# transmission discrepancy is  20.624033462756433
# =============EPOCH 130===============
# Utility is  5.605996448942771
# Cost is  -10.875190126677037
# nodalPrice discrepancy is  9.030714308029573
# transmission discrepancy is  20.455579843441676
# =============EPOCH 131===============
# Utility is  6.455710716552305
# Cost is  -10.888279270386583
# nodalPrice discrepancy is  8.117912699057515
# transmission discrepancy is  18.400420082107654
# =============EPOCH 132===============
# Utility is  6.393946819549105
# Cost is  -11.52764126841432
# nodalPrice discrepancy is  13.118126953319875
# transmission discrepancy is  16.494972975164103
# =============EPOCH 133===============
# Utility is  6.509902569396787
# Cost is  -10.916073992483811
# nodalPrice discrepancy is  8.458115875244783
# transmission discrepancy is  16.52417317244843
# =============EPOCH 134===============
# Utility is  6.488648854779145
# Cost is  -10.931594358648516
# nodalPrice discrepancy is  7.425358960378118
# transmission discrepancy is  17.32996566653519
# =============EPOCH 135===============
# Utility is  6.0419152713981745
# Cost is  -10.948277332970562
# nodalPrice discrepancy is  8.137263922436201
# transmission discrepancy is  28.37375314952415
# =============EPOCH 136===============
# Utility is  6.612690696526023
# Cost is  -10.940745113817712
# nodalPrice discrepancy is  8.26595118841594
# transmission discrepancy is  15.086339785596227
# =============EPOCH 137===============
# Utility is  6.4445131794043835
# Cost is  -10.960529378786035
# nodalPrice discrepancy is  7.791804896052124
# transmission discrepancy is  16.913669677710956
# =============EPOCH 138===============
# Utility is  6.073613957727093
# Cost is  -10.968996951710396
# nodalPrice discrepancy is  8.571598828839853
# transmission discrepancy is  22.49771289621755
# =============EPOCH 139===============
# Utility is  6.483709678149207
# Cost is  -10.956249977851225
# nodalPrice discrepancy is  10.791695800587872
# transmission discrepancy is  13.292240061613393
# =============EPOCH 140===============
# Utility is  6.365260236645408
# Cost is  -10.96830523234542
# nodalPrice discrepancy is  6.82569952602075
# transmission discrepancy is  19.39242910609802
# =============EPOCH 141===============
# Utility is  6.5674131903735145
# Cost is  -10.994099616747757
# nodalPrice discrepancy is  15.486380055289507
# transmission discrepancy is  15.299052432861616
# =============EPOCH 142===============
# Utility is  6.571037017085128
# Cost is  -11.73001956265478
# nodalPrice discrepancy is  19.812010521400087
# transmission discrepancy is  12.392135892282683
# =============EPOCH 143===============
# Utility is  6.483118078570753
# Cost is  -11.003954570778756
# nodalPrice discrepancy is  9.857598410958508
# transmission discrepancy is  15.734474576972096
# =============EPOCH 144===============
# Utility is  6.33719953580916
# Cost is  -11.013793102355788
# nodalPrice discrepancy is  8.704064279057988
# transmission discrepancy is  18.046721077101594
# =============EPOCH 145===============
# Utility is  6.218621908578632
# Cost is  -10.993832838415447
# nodalPrice discrepancy is  13.408878646323357
# transmission discrepancy is  18.04837382222114
# =============EPOCH 146===============
# Utility is  5.792477616682466
# Cost is  -11.202137842334269
# nodalPrice discrepancy is  15.032372173467984
# transmission discrepancy is  34.21434210338425
# =============EPOCH 147===============
# Utility is  6.275623071497501
# Cost is  -10.98018402593695
# nodalPrice discrepancy is  9.785087170164092
# transmission discrepancy is  24.045929782238755
# =============EPOCH 148===============
# Utility is  5.978550597896529
# Cost is  -10.979354091278086
# nodalPrice discrepancy is  8.154819348900984
# transmission discrepancy is  31.032908438664506
# =============EPOCH 149===============
# Utility is  6.130569080661932
# Cost is  -10.958309129427679
# nodalPrice discrepancy is  9.45996229339118
# transmission discrepancy is  28.748884845739212
# =============EPOCH 150===============
# Utility is  6.2094164036728685
# Cost is  -10.951472691398946
# nodalPrice discrepancy is  10.738652078153674
# transmission discrepancy is  23.361681838041637
# =============EPOCH 151===============
# Utility is  6.43675764281791
# Cost is  -10.94533061636932
# nodalPrice discrepancy is  8.885780866857054
# transmission discrepancy is  21.12120799507646
# =============EPOCH 152===============
# Utility is  6.695999999999999
# Cost is  -10.956448464780326
# nodalPrice discrepancy is  6.82499533864354
# transmission discrepancy is  16.177538009166966
# =============EPOCH 153===============
# Utility is  6.173850308864379
# Cost is  -10.981275554450743
# nodalPrice discrepancy is  10.641251501229142
# transmission discrepancy is  25.466261329350363
# =============EPOCH 154===============
# Utility is  6.239801718539228
# Cost is  -10.978463253495216
# nodalPrice discrepancy is  7.167071689402896
# transmission discrepancy is  28.06245363432523
# =============EPOCH 155===============
# Utility is  6.477705418800428
# Cost is  -10.918329413875803
# nodalPrice discrepancy is  11.325920671789131
# transmission discrepancy is  21.688597457504848
# =============EPOCH 156===============
# Utility is  6.2938595280677525
# Cost is  -10.984090244298784
# nodalPrice discrepancy is  10.768542770409129
# transmission discrepancy is  20.625529442809984
# =============EPOCH 157===============
# Utility is  6.295436903402146
# Cost is  -11.154749234075247
# nodalPrice discrepancy is  14.663944617089644
# transmission discrepancy is  25.580709285607025
# =============EPOCH 158===============
# Utility is  6.36534886580526
# Cost is  -10.985088988547874
# nodalPrice discrepancy is  11.683844963360885
# transmission discrepancy is  15.726577578130167
# =============EPOCH 159===============
# Utility is  6.631441313307589
# Cost is  -10.989591089290721
# nodalPrice discrepancy is  12.58361482621278
# transmission discrepancy is  13.52251761999646
# =============EPOCH 160===============
# Utility is  6.65882617938566
# Cost is  -11.008132392755508
# nodalPrice discrepancy is  10.96134101786967
# transmission discrepancy is  13.206190209736993
# =============EPOCH 161===============
# Utility is  6.2060865094351225
# Cost is  -11.147071938543368
# nodalPrice discrepancy is  14.23543197678913
# transmission discrepancy is  23.874974648508008
# =============EPOCH 162===============
# Utility is  6.335993039068242
# Cost is  -11.026931862281947
# nodalPrice discrepancy is  9.077314140592348
# transmission discrepancy is  19.974455219735134
# =============EPOCH 163===============
# Utility is  6.4136088401554225
# Cost is  -11.02585930083071
# nodalPrice discrepancy is  9.366973519346734
# transmission discrepancy is  10.669801368752639
# =============EPOCH 164===============
# Utility is  6.047837098768956
# Cost is  -11.02787584709298
# nodalPrice discrepancy is  7.272027294038484
# transmission discrepancy is  23.010862243216216
# =============EPOCH 165===============
# Utility is  6.4809393282056975
# Cost is  -11.011226993980484
# nodalPrice discrepancy is  6.718119828449995
# transmission discrepancy is  17.509879538077396
# =============EPOCH 166===============
# Utility is  6.343670804193456
# Cost is  -11.169203787022855
# nodalPrice discrepancy is  15.256439889950395
# transmission discrepancy is  23.243271128050292
# =============EPOCH 167===============
# Utility is  6.236099520195957
# Cost is  -11.02597974020579
# nodalPrice discrepancy is  9.352408602241876
# transmission discrepancy is  19.59220844768577
# =============EPOCH 168===============
# Utility is  6.117968410951756
# Cost is  -11.02214045706898
# nodalPrice discrepancy is  12.123769751785183
# transmission discrepancy is  25.47720891807389
# =============EPOCH 169===============
# Utility is  6.339896058558958
# Cost is  -11.311935487570906
# nodalPrice discrepancy is  15.010050026636204
# transmission discrepancy is  22.424273772732537
# =============EPOCH 170===============
# Utility is  5.858392323019985
# Cost is  -11.010402319002534
# nodalPrice discrepancy is  8.001573776629186
# transmission discrepancy is  30.209416930968324
# =============EPOCH 171===============
# Utility is  6.510521521478206
# Cost is  -10.982316650191688
# nodalPrice discrepancy is  5.915327734711304
# transmission discrepancy is  19.162679169232945
# =============EPOCH 172===============
# Utility is  6.513556312894323
# Cost is  -10.992037691982116
# nodalPrice discrepancy is  8.972870262488405
# transmission discrepancy is  12.547856654858068
# =============EPOCH 173===============
# Utility is  6.022165770714961
# Cost is  -11.004061976430807
# nodalPrice discrepancy is  10.590711169481484
# transmission discrepancy is  31.30733872006262
# =============EPOCH 174===============
# Utility is  5.942688334022708
# Cost is  -10.994728152171184
# nodalPrice discrepancy is  15.75244289145557
# transmission discrepancy is  26.829115443533603
# =============EPOCH 175===============
# Utility is  5.899373772749445
# Cost is  -10.966352981261188
# nodalPrice discrepancy is  6.436064876332305
# transmission discrepancy is  25.932697297837993
# =============EPOCH 176===============
# Utility is  6.410867069624126
# Cost is  -10.9386298162673
# nodalPrice discrepancy is  7.86936819393898
# transmission discrepancy is  19.6558982760099
# =============EPOCH 177===============
# Utility is  5.805052802426182
# Cost is  -10.946172537680619
# nodalPrice discrepancy is  9.798954603228392
# transmission discrepancy is  37.08313241841071
# =============EPOCH 178===============
# Utility is  5.938118428569256
# Cost is  -10.916252734501594
# nodalPrice discrepancy is  8.95138334815527
# transmission discrepancy is  29.418184861028635
# =============EPOCH 179===============
# Utility is  6.048725969337995
# Cost is  -10.873589731663396
# nodalPrice discrepancy is  10.72023237857555
# transmission discrepancy is  28.302320641723867
# =============EPOCH 180===============
# Utility is  6.172777434679493
# Cost is  -10.88417151851312
# nodalPrice discrepancy is  7.806258586813487
# transmission discrepancy is  24.747890257584487
# =============EPOCH 181===============
# Utility is  6.570981470370633
# Cost is  -10.87779261793015
# nodalPrice discrepancy is  6.2806348426641465
# transmission discrepancy is  13.620951372000489
# =============EPOCH 182===============
# Utility is  6.315515109501194
# Cost is  -10.897342840538355
# nodalPrice discrepancy is  9.942880851842313
# transmission discrepancy is  24.71619148353883
# =============EPOCH 183===============
# Utility is  6.249104015573122
# Cost is  -10.91402738419264
# nodalPrice discrepancy is  11.504738613491094
# transmission discrepancy is  32.56156340027154
# =============EPOCH 184===============
# Utility is  6.264641373177932
# Cost is  -10.906698801993425
# nodalPrice discrepancy is  6.3628205513535825
# transmission discrepancy is  27.750443821606453
# =============EPOCH 185===============
# Utility is  5.780691228883935
# Cost is  -10.914110938655629
# nodalPrice discrepancy is  10.727621896849792
# transmission discrepancy is  39.21583330187403
# =============EPOCH 186===============
# Utility is  6.3678991029288285
# Cost is  -10.889287541921373
# nodalPrice discrepancy is  7.256696722644569
# transmission discrepancy is  19.893910779186662
# =============EPOCH 187===============
# Utility is  6.258744676904634
# Cost is  -11.135493081503721
# nodalPrice discrepancy is  13.790276643268834
# transmission discrepancy is  21.236809188164216
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-3b6598747635> in <module>
#       5   envNode1.load = load_1 + transmissionVolume
#       6   envNode2.nodalPrice = nodalPrice
# ----> 7   trainingNode1()
#       8   trainingNode2()
#       9   with torch.no_grad():
#
# <ipython-input-7-a078ccaf8252> in trainingNode1()
#       5     action,log_prob = agent1.select_action(observation,time_interval)
#       6     new_observation,cP,action,new_time_interval = envNode1.step(action)
# ----> 7     agent1.update_policy(observation,action,log_prob,cP,new_observation,time_interval)
#       8     observation = new_observation
#       9     time_interval = new_time_interval
#
# <ipython-input-4-7041b1c9df77> in update_policy(self, state, action, log_prob, reward, next_state, time_interval)
#      76           print(type(target))
#      77         loss_critic.backward()
# ---> 78         self.critic_optim_dict[time_interval].step()
#      79
#      80         #==============Update Actor==================
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     111                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112                 with torch.autograd.profiler.record_function(profile_name):
# --> 113                     return func(*args, **kwargs)
#     114             return wrapper
#     115
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     111                 and returns the loss.
#     112         """
# --> 113         self._cuda_graph_capture_health_check()
#     114
#     115         loss = None
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in _cuda_graph_capture_health_check(self)
#      82
#      83     # Currently needed by Adam and AdamW
# ---> 84     def _cuda_graph_capture_health_check(self):
#      85         if torch.has_cuda and torch.cuda.is_available():
#      86             capturing = torch.cuda.is_current_stream_capturing()
#
# KeyboardInterrupt:
