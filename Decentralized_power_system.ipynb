# %%
import os
os.chdir('/content/drive/MyDrive/research/power system/power_system_DM5_803')

# %%
import numpy as np
from torch.distributions import Categorical, Normal
from memory import Memory
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam,SGD
from util import *
from copy import deepcopy
from torch.optim.lr_scheduler import ExponentialLR

# %%
def fanin_init(size, fanin=None):
    fanin = fanin or size[0]
    v = 1. / np.sqrt(fanin)
    return torch.Tensor(size).uniform_(-v, v)
class Actor(nn.Module):
    def __init__(self, nb_states, nb_actions, hidden1=128, hidden2=128, init_w=3e-3):
        super(Actor, self).__init__()
        #self.constraints = constraints
        self.fc1 = nn.Linear(nb_states, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden2,nb_actions) #production
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
        self.init_weights(init_w)
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    def forward(self,x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.tanh(out)#[-1,1]
        return out
class Critic(nn.Module):
    def __init__(self,nb_states,nb_actions,hidden1 = 128,hidden2 = 128,init_w = 3e-3):
        super(Critic, self).__init__()
       # self.constraints = constraints
        self.fc1 = nn.Linear(nb_states+nb_actions, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden2, 1) 
        self.relu = nn.ReLU()
        self.init_weights(init_w)
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    def forward(self,state,action):
        x = torch.concat((state,action),dim = 1)
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        return out
    def mc(self,state,action):
      state.requires_grad = False
      action.requires_grad = True
      self.forward(state,action).backward()
      return action.grad.item()

# %%
criterion = nn.MSELoss()
class DDPG(object):
    def __init__(self, nb_interval,nb_states,nb_actions, constraints, args):
        if args.seed > 0:
            self.seed(args.seed)
        self.constraints = constraints
        self.nb_interval = nb_interval
        self.nb_states = nb_states
        self.nb_actions = nb_actions
        assert self.nb_states.shape[0] == self.nb_interval
        # Create Actor and Critic Network
        net_cfg = {
            'hidden1':args.hidden1, 
            'hidden2':args.hidden2, 
            'init_w':args.init_w
        }

        self.actor_dict = dict()
        self.actor_target_dict = dict()
        self.actor_optim_dict = dict()
        self.actor_scheduler_dict = dict()


        self.critic_dict = dict()
        self.critic_target_dict = dict()
        self.critic_optim_dict = dict()
        self.critic_scheduler_dict = dict()

        self.memory_dict = dict()

        #build a model for each time interval
        for i in range(self.nb_interval):

            self.actor_dict[i] = Actor(self.nb_states[i],self.nb_actions, **net_cfg)
            self.actor_target_dict[i] = Actor(self.nb_states[i],self.nb_actions, **net_cfg)
            self.actor_optim_dict[i] = Adam(self.actor_dict[i].parameters(), lr=args.prate )
            self.actor_scheduler_dict[i] = ExponentialLR(self.actor_optim_dict[i],gamma = args.actorDecay)

            hard_update(self.actor_target_dict[i],self.actor_dict[i])
            
            self.critic_dict[i] = Critic(self.nb_states[i], self.nb_actions, **net_cfg)
            self.critic_target_dict[i] = Critic(self.nb_states[i],self.nb_actions,  **net_cfg)
            self.critic_optim_dict[i] = Adam(self.critic_dict[i].parameters(), lr=args.rate)
            self.critic_scheduler_dict[i] = ExponentialLR(self.critic_optim_dict[i],gamma = args.criticDecay)
            hard_update(self.critic_target_dict[i],self.critic_dict[i])



            
            #Create replay buffer
            self.memory_dict[i] = Memory(limit=args.rmsize)

        # Hyper-parameters
        self.batch_size = args.bsize
        self.tau = args.tau
        self.discount = args.discount

        # 
        self.s_t = None # Most recent state
        self.a_t = None # Most recent action
        self.is_training = True

        # 
        if USE_CUDA: self.cuda()

    def update_policy(self,time_interval):
        # Sample batch
        state_batch, action_batch, reward_batch, \
        next_state_batch = self.memory_dict[time_interval].sample_and_split(self.batch_size)

        # Prepare for the target q batch
        with torch.no_grad():
            if time_interval != self.nb_interval-1:
                next_q_values = self.critic_target_dict[time_interval+1](
                    to_tensor(next_state_batch),
                    self.actor_target_dict[time_interval+1](to_tensor(next_state_batch)),
                )

                target_q_batch = to_tensor(reward_batch) + \
                    self.discount*next_q_values
            else:
                target_q_batch = to_tensor(reward_batch)
        # Critic update
        self.critic_dict[time_interval].zero_grad()

        q_batch = self.critic_dict[time_interval]( to_tensor(state_batch), to_tensor(action_batch) )
        
        try:
            value_loss = criterion(torch.flatten(q_batch), torch.flatten(target_q_batch))
        except RuntimeError:
            print(torch.flatten(q_batch).shape)
            print(torch.flatten(target_q_batch).shape)
        try:
            value_loss.backward()
        except RuntimeError:
            print(q_batch)
            print(value_loss)
        self.critic_optim_dict[time_interval].step()

        # Actor update
        self.actor_dict[time_interval].zero_grad()

        policy_loss = -self.critic_dict[time_interval](
            to_tensor(state_batch),
            self.actor_dict[time_interval](to_tensor(state_batch))
        )


        policy_loss = policy_loss.mean()
        #policy_loss.requires_grad = True
        policy_loss.backward()
        self.actor_optim_dict[time_interval].step()

        # Target update
        soft_update(self.actor_target_dict[time_interval], self.actor_dict[time_interval], self.tau)
        soft_update(self.critic_target_dict[time_interval], self.critic_dict[time_interval], self.tau)
        self.actor_scheduler_dict[time_interval].step()
        self.critic_scheduler_dict[time_interval].step()

    def cuda(self):
        for i in range(self.nb_interval):
            self.actor_dict[i].cuda()
            self.actor_target_dict[i].cuda()
            self.critic_dict[i].cuda()
            self.critic_target_dict[i].cuda()

    def observe(self,s_t,a_t, r_t,s_t1,  time_interval):
        self.memory_dict[time_interval].append(s_t,a_t, r_t, s_t1)


    def random_action(self):
        action_cont = np.random.uniform(-1.,1.,size = (self.nb_actions,))
        return action_cont

    def select_action(self, s_t,time_interval):
        action_continuous = to_numpy(
            self.actor_dict[time_interval](to_tensor(np.array([s_t])))
        ).squeeze(0)


        return action_continuous

    def reset(self, obs):
        self.s_t = obs
        #self.random_process.reset_states()


    def seed(self,s):
        torch.manual_seed(s)
        if USE_CUDA:
            torch.cuda.manual_seed(s)
    def get_mc(self,s_t,action,time_interval):
      return self.critic_dict[time_interval].mc(to_tensor(np.array([s_t])),to_tensor(np.array([action])))

# %%
def rescale_action(action,lb,ub):
    return action * (ub- lb) / 2.0 +\
            (lb + ub) / 2.0
class Environment(object):
    def __init__(self, constraints,cost_func,elastic_load_func,load,impedance,nb_interval,gaussian_noise):
        self.constraints = constraints
        self.cost_func = cost_func
        self.elastic_load_func= elastic_load_func
        self.load = load
        self.impedance = impedance
        self.nb_interval = nb_interval
        self.gaussian_noise = gaussian_noise
        self.normal_scale = constraints['normal_scale']
        self.mc = np.array([0.]*nb_interval)
        self.trans = np.array([0.]*nb_interval)
        self.reset()
    def reset(self):
        self.battery_node1 = 0.0
        self.battery_node2 = 0.0
        self.observation_node1 =  np.array([self.battery_node1*self.constraints['battery_scale'],\
            (self.load[0]+self.trans[0])*self.constraints['load_scale']])
        self.observation_node2 = np.array([self.battery_node2*self.constraints['battery_scale'], self.mc[0]]) 
        self.state_node1 = np.array([self.battery_node1,\
            (self.load[0]+self.trans[0])])
        self.state_node2 = np.array([self.battery_node2,self.mc[0]])
        self.time_interval = 0
    def get_obs(self):
        return self.observation_node1,self.observation_node2,self.time_interval
    def reward(self,true_action,time_interval):
        if type(time_interval) != int:
            print(time_interval) 
        a_p,a_c1,a_c2,a_t,a_el,e_p,e_el,e_c1,e_c2 = true_action
        prod_cost = self.cost_func(e_p)

        #penalty for Node 1:
        penaltyForNode1 = -100*np.abs(a_p-e_p) - 100*np.abs(e_c1-a_c1)
        #penalty for Node 2:
        penaltyForNode2 = -100*np.abs(a_el-e_el)- 100*np.abs(e_c2-a_c2) - 1*np.abs(self.trans[time_interval]-a_t)
     
        
        el_profit = self.elastic_load_func(e_el)
        trans_cost = a_t*self.mc[time_interval]#negative
        return prod_cost , el_profit, trans_cost, penaltyForNode1,penaltyForNode2
    
    """
    the actions ouputed from Actors are in [-1,1], this function transfer them to actual values
    """   
    def make_action(self,action1, action2,t = None):
        if t is None:
            t = self.time_interval
        a_c1 = action1.item()#Charging of Node 1
        a_t,a_c2 = action2 # transmission and charging of Node 2
        load_t = self.load[t] + self.trans[t] #For node 1, the transmission work the same as fixed load.
        
        if self.gaussian_noise: #adding noise to actions for exploration

            a_c1 += np.random.normal(scale = self.normal_scale) 
            a_c1 = np.clip(a_c1,-1,1)
            
            a_c2 += np.random.normal(scale = self.normal_scale) 
            a_c2 = np.clip(a_c2,-1,1)
            
            a_t += np.random.normal(scale = self.normal_scale) 
            a_t = np.clip(a_t,-1,1)


        trans_t = rescale_action(a_t,0,self.constraints['max_angle']/self.impedance) #rescale it to true value (it is in [0,80])
        
        a_c1 = rescale_action(a_c1,-200,200)  #rescale it to true value ([-200,200])
        a_c2  = rescale_action(a_c2,-200,200) #rescale it to true value ([-200,200])
        
        
        lb_p = 0 #lower bound of production is 0
        ub_p = 600 #upper bound of procution is 600
        
        lb_el = 0 #lower bound of elastic load is 0
        ub_el = 150 #upper bound of elstic load is 150 (this can be adjusted)
        
        lb_c1 = -self.battery_node1 #lower bound of charging (or upper bound of discharging) of Node 1 is the energy in the battery
        ub_c1 = self.constraints['max_energy']-self.battery_node1 #upper bound of charging of Nope 2 is {battery capacity - current energy}

        lb_c2 = -self.battery_node2 #lower bound of charging (or upper bound of discharging) of Node 2 is the energy in the battery
        ub_c2 = self.constraints['max_energy']-self.battery_node2 #upper bound of charging of Nope 2 is {battery capacity - current energy}

        
        effective_c1 = np.minimum(np.maximum(a_c1, lb_c1),ub_c1) #compute the feasible charging decision
        effective_c2 = np.minimum(np.maximum(a_c2,lb_c2),ub_c2)
 
        a_p = effective_c1 + load_t #compute the production by power balance of Node 1
        a_el = trans_t - effective_c2 #compute the elastic load by power balance of Node 2

        effective_p =  np.minimum(np.maximum(a_p,lb_p),ub_p)  #compute the feasible production decision
        effective_el = np.maximum(a_el,lb_el)#compute the feasible elastic load decision 


        return np.array([a_p,a_c1,a_c2,trans_t,a_el,effective_p,effective_el,effective_c1,effective_c2])
        # return procution, charging of node 1, charging of node 2, transmission, elastic load, feasible proction, feasible elastic load, feasible charging 1 ,feasible charging 2

    def scale_decay(self): #decrease the noise variance (if applicable)
        self.normal_scale *= self.constraints['decay_rate']

    
    """
    update the marginal cost and transmission volume in the environment 
    """
    def updateMcAndTrans(self,new_mc,new_trans,updateRate,time_interval): 
        self.mc[time_interval] = (1-updateRate) * self.mc[time_interval] + updateRate*new_mc
        self.trans[time_interval] = (1-updateRate) * self.trans[time_interval] + updateRate*new_trans
    def step(self,action1,action2):
        action1_copy = deepcopy(action1)
        action2_copy = deepcopy(action2)
        true_action = self.make_action(action1,action2)
        r_1,r_2,r_t,pForN1,pForN2 = self.reward(true_action,self.time_interval)
        r_1 *= self.constraints['reward_scale']
        r_2 *= self.constraints['reward_scale']
        r_t *= self.constraints['reward_scale']#negative
        pForN1 *= self.constraints['reward_scale']
        pForN2 *= self.constraints['reward_scale']
        if self.time_interval == self.nb_interval -1:
            self.reset()
            return self.observation_node1,self.observation_node2,r_1,r_2,r_t,pForN1,pForN2,action1_copy,action2_copy,self.time_interval
        else:
            a_p,a_c1,a_c2,a_t,el,eP,eEl,eC1,eC2 = true_action
            self.battery_node1 += eC1
            self.battery_node2 += eC2
            self.time_interval += 1
            self.state_node1 =np.array([self.battery_node1,(self.load[self.time_interval]+self.trans[self.time_interval])\
              ])
            self.state_node2 = np.array([self.battery_node2,self.mc[self.time_interval]\
               ])
            self.observation_node1 = np.array([self.battery_node1*self.constraints['battery_scale'],(self.load[self.time_interval]+self.trans[self.time_interval])*self.constraints['load_scale']\
              ])
            self.observation_node2 = np.array([self.battery_node2*self.constraints['battery_scale'],self.mc[self.time_interval]\
               ])

            
            return self.observation_node1,self.observation_node2,r_1,r_2,r_t,pForN1,pForN2,action1_copy,action2_copy,self.time_interval

# %%
import logging
import sys
import argparse
import datetime

# %%
constraints = dict()
constraints['max_prod'] = 600
constraints['max_charge'] = 200
constraints['max_energy'] = 280
constraints['max_angle'] = 0.08
constraints['load_scale'] = 0.005
constraints['mc_scale'] = 0.05
constraints['battery_scale'] = 0.01
constraints['reward_scale'] = 0.0001
constraints['normal_scale'] = 0.05
constraints['decay_rate'] = 0.99

# %%
def cost_func(x):
  return -(20+2*x+0.02*x**2)
def elastic_load_func(x):
  return -0.02*x**2 + 12*x +5
def mc_func(x):
  return -0.04*x-2
 
impedance = 0.001
startup = 30
nb_interval = 8
nb_states_1 = np.array([1+1 for x in range(nb_interval)])
nb_states_2 = np.array([1+1 for x in range(nb_interval)])
nb_actions1 = 1
nb_actions2 = 2
load_1 = np.array([100,80,70,75,150,180,220,200]).astype(np.float32)
#load_1 = np.array([100,80,70]).astype(np.float32)
#load_1 = np.array([100])
#load_2 = np.array([120,100,80,80,170,200,230,200])
#load_2 = np.array([120,100,80,80,170,200,150,200])

# %%
parser = argparse.ArgumentParser(description='Power system DDPG')

parser.add_argument('--hidden1', default=128, type=int, help='hidden num of first fully connect layer')
parser.add_argument('--hidden2', default=256, type=int, help='hidden num of second fully connect layer')
parser.add_argument('--rate', default=0.01, type=float, help='learning rate')
parser.add_argument('--actorDecay', default=0.9995, type=float, help='gamma for actor optimization schedular')
parser.add_argument('--criticDecay', default=0.99995, type=float, help='gamma for critic optimization schedular')
parser.add_argument('--prate', default=0.001, type=float, help='policy net learning rate (only for DDPG)')
parser.add_argument('--warmup', default=5000, type=int, help='time without training but only filling the replay memory')
parser.add_argument('--discount', default=1., type=float, help='')
parser.add_argument('--bsize', default=256, type=int, help='minibatch size')
parser.add_argument('--rmsize', default=50000, type=int, help='memory size')
parser.add_argument('--tau', default=0.9, type=float, help='moving average for target network')
parser.add_argument('--init_w', default=0.03, type=float, help='') 
parser.add_argument('--train_iter', default=100000, type=int, help='train iters each timestep')
parser.add_argument('--seed', default=123, type=int, help='')
args = parser.parse_args("")

# %%
np.random.seed(123)

# %%
randomness = False #no gaussian noise if False
agent1 = DDPG(nb_interval,nb_states_1,nb_actions1, constraints, args)
agent2 = DDPG(nb_interval,nb_states_2,nb_actions2, constraints, args)
env = Environment(constraints,cost_func,elastic_load_func,load_1,impedance,nb_interval,randomness)

# %%
step = 0
episodeRewardNode1= 0.
episodeRewardNode2 = 0.
episodePenaltyNode1 = 0.
episodePenaltyNode2 = 0.
env.reset()
observation_1,observation_2,time_interval = env.get_obs()
trans_replay = []
trans_discrepancy = []
mc_rate = 0.5
while step < args.train_iter:


    if step < args.warmup:
        action1 = agent1.random_action()
        action2 = agent2.random_action()
    else:
      action1 = agent1.select_action(observation_1,time_interval)
      action2 = agent2.select_action(observation_2,time_interval)
      
      
    new_observation_1,new_observation_2,reward_1,reward_2,reward_t,penaltyForNode1,penaltyForNode2,action1,action2 ,new_time_interval = env.step(action1,action2)
    
    
    
    agent1.observe(observation_1,action1,reward_1+penaltyForNode1,new_observation_1,time_interval)
    agent2.observe(observation_2,action2,reward_2+reward_t + penaltyForNode2,new_observation_2,time_interval)

    true_action = env.make_action(deepcopy(action1),deepcopy(action2))
    a_p,a_c1,a_c2,a_t,el,eP,eEl,eC1,eC2 = true_action

    trans_discrepancy.append(np.abs(a_t-env.trans[time_interval]))
    new_mc = mc_func(a_p)
    new_trans = a_t
    env.updateMcAndTrans(new_mc,new_trans,0.5,time_interval)
    #update marginal cost
    #env.update_mc(mc_func(a_p),mc_rate*(step/100)**(-0.9),time_interval)
    
    if step > args.warmup and time_interval == 0:
      for k in range(env.nb_interval):
        agent1.update_policy(k)
        agent2.update_policy(k)


    observation_1 = new_observation_1
    observation_2 = new_observation_2
    time_interval = new_time_interval



    step += 1
    episodeRewardNode1 += reward_1 
    episodeRewardNode2 += reward_2# +reward_t

    episodePenaltyNode1 += penaltyForNode1
    episodePenaltyNode2 += penaltyForNode2
    #episode_reward += reward_1+reward_2 + penaltyForNode1+ penaltyForNode2
    if time_interval == 0 and display and step % 100 ==0:
        print("episode {} reward of Node 1 is {}\n".format(step,episodeRewardNode1)  )
        print("episode {} reward of Node 2 is {}\n".format(step,episodeRewardNode2))
        print("episode {} penalty of Node 1 is {}\n".format(step,episodePenaltyNode1) )
        print("episode {} penalty of Node 2 is {}\n".format(step,episodePenaltyNode2) )
        print("episode {} transmission discrepancy is".format(step),trans_discrepancy,"\n")

    if time_interval == 0:
        episodeRewardNode1 = 0.
        episodeRewardNode2 =0.
        episodePenaltyNode1 = 0.
        episodePenaltyNode2 = 0.
        trans_discrepancy = []
    if False and step > 3000:
        env.scale_decay()
# Out:
# episode 200 reward of Node 1 is -1.0987635230466115
#
# episode 200 reward of Node 2 is 0.38677642397732537
#
# episode 200 penalty of Node 1 is -2.624460518249437
#
# episode 200 penalty of Node 2 is -2.5398270393118985
#
# episode 200 transmission discrepancy is [19.114259513753055, 24.07247233802287, 17.55564257316705, 51.67849577087122, 25.541940232991568, 19.437017951824153, 15.865573293289081, 35.85385691112914]
#
# episode 400 reward of Node 1 is -1.1860757208876824
#
# episode 400 reward of Node 2 is 0.35950720698256483
#
# episode 400 penalty of Node 1 is -3.600244702857447
#
# episode 400 penalty of Node 2 is -5.882760140632129
#
# episode 400 transmission discrepancy is [33.706253778982585, 19.406809243992043, 59.82977011960531, 46.56859881794876, 4.963691622333169, 37.542628932370455, 31.00777229007554, 57.473030604736174]
#
# episode 600 reward of Node 1 is -1.2945243626880574
#
# episode 600 reward of Node 2 is 0.43668329873583883
#
# episode 600 penalty of Node 1 is -2.2560281768058648
#
# episode 600 penalty of Node 2 is -6.9363695880215985
#
# episode 600 transmission discrepancy is [3.209676592906945, 43.14751306332291, 36.825273045607375, 14.01802333572828, 27.008429302757424, 26.852843703297, 4.320635239465815, 30.029789172787606]
#
# episode 800 reward of Node 1 is -1.045620053878774
#
# episode 800 reward of Node 2 is 0.29091039495481014
#
# episode 800 penalty of Node 1 is -1.6866791377965464
#
# episode 800 penalty of Node 2 is -5.017669816878416
#
# episode 800 transmission discrepancy is [30.24941309776655, 18.40993978158992, 44.72774534990187, 22.515103535292006, 15.697749960508045, 56.889676248158004, 12.567654363852071, 47.964547914566495]
#
# episode 1000 reward of Node 1 is -0.8355625510489197
#
# episode 1000 reward of Node 2 is 0.34620241906351595
#
# episode 1000 penalty of Node 1 is -2.1866905829706216
#
# episode 1000 penalty of Node 2 is -3.5092910111181355
#
# episode 1000 transmission discrepancy is [6.463752940013116, 34.68697955678781, 27.3165635455058, 12.526440032192063, 42.285634507715386, 17.923250348220282, 13.973897599547726, 6.451492824638784]
#
# episode 1200 reward of Node 1 is -1.2850109089971613
#
# episode 1200 reward of Node 2 is 0.3595953428252853
#
# episode 1200 penalty of Node 1 is -1.1018910414846688
#
# episode 1200 penalty of Node 2 is -5.125230009181914
#
# episode 1200 transmission discrepancy is [6.8374999255326685, 2.531035431132711, 3.151553175202551, 25.48498667774733, 29.633501901551014, 18.336568582967757, 2.9284149594017848, 11.517900182376174]
#
# episode 1400 reward of Node 1 is -1.1463469124849082
#
# episode 1400 reward of Node 2 is 0.47053560992701143
#
# episode 1400 penalty of Node 1 is -0.5226697811958784
#
# episode 1400 penalty of Node 2 is -4.201599594105103
#
# episode 1400 transmission discrepancy is [1.7666696089011822, 33.336541220048126, 5.723256779063746, 8.481764761858614, 14.933145596774196, 42.14954248822867, 14.990258816078097, 7.674966041091601]
#
# episode 1600 reward of Node 1 is -1.109118376514691
#
# episode 1600 reward of Node 2 is 0.4063811303412948
#
# episode 1600 penalty of Node 1 is -1.7387390655463908
#
# episode 1600 penalty of Node 2 is -4.9470058813876845
#
# episode 1600 transmission discrepancy is [8.273079243041174, 22.71017011422842, 39.84189326916937, 33.064627829463, 36.15845654643353, 38.08117764026077, 37.96892889137315, 29.65471306329666]
#
# episode 1800 reward of Node 1 is -1.197442144493163
#
# episode 1800 reward of Node 2 is 0.26320495612703565
#
# episode 1800 penalty of Node 1 is -2.375293580306592
#
# episode 1800 penalty of Node 2 is -3.382579766945793
#
# episode 1800 transmission discrepancy is [36.71308947213501, 7.658045476267439, 20.803844333325927, 14.586549423556441, 19.034032861494467, 14.752349498487618, 20.77104793058566, 0.6243426220518344]
#
# episode 2000 reward of Node 1 is -1.1313607831909258
#
# episode 2000 reward of Node 2 is 0.31769990454969904
#
# episode 2000 penalty of Node 1 is -6.9631141749017615
#
# episode 2000 penalty of Node 2 is -3.6878694959954696
#
# episode 2000 transmission discrepancy is [13.461931871292698, 17.01191983087098, 14.046452148205859, 41.43763994858099, 55.32396683072077, 7.232480934473031, 64.04902489776228, 10.642034240307531]
#
# episode 2200 reward of Node 1 is -1.0325313907865699
#
# episode 2200 reward of Node 2 is 0.24443776334557427
#
# episode 2200 penalty of Node 1 is -3.3793604382211857
#
# episode 2200 penalty of Node 2 is -9.466113679458962
#
# episode 2200 transmission discrepancy is [25.793725811796563, 16.64094709991675, 0.23618476752276507, 15.965066004463445, 19.845046014367313, 14.870202991098061, 8.36775267071063, 13.227447592076182]
#
# episode 2400 reward of Node 1 is -1.0678192097524541
#
# episode 2400 reward of Node 2 is 0.47282200195108526
#
# episode 2400 penalty of Node 1 is -1.4674871172374282
#
# episode 2400 penalty of Node 2 is -4.31803815971301
#
# episode 2400 transmission discrepancy is [4.1978399474078145, 31.523425836117433, 7.978215317202931, 14.128714846814269, 35.64977242643007, 30.37998581478091, 21.252830347962913, 62.93541325485762]
#
# episode 2600 reward of Node 1 is -0.8984622510633309
#
# episode 2600 reward of Node 2 is 0.3252292161974213
#
# episode 2600 penalty of Node 1 is -1.148962642095155
#
# episode 2600 penalty of Node 2 is -6.430256814653315
#
# episode 2600 transmission discrepancy is [23.065430080959686, 22.354003551987688, 28.85738789256154, 36.251549619023535, 32.58791158671964, 7.271862386769271, 3.494730485844734, 7.028960558564702]
#
# episode 2800 reward of Node 1 is -0.9688343747709341
#
# episode 2800 reward of Node 2 is 0.2955042304159994
#
# episode 2800 penalty of Node 1 is -2.132251183948355
#
# episode 2800 penalty of Node 2 is -2.9999475909372824
#
# episode 2800 transmission discrepancy is [5.410326257568343, 68.43851142135047, 34.0559139796478, 55.61545547345996, 31.260164386950557, 55.11376020858135, 9.931184999498349, 23.32934274993415]
#
# episode 3000 reward of Node 1 is -1.0877506421839283
#
# episode 3000 reward of Node 2 is 0.3492649941838617
#
# episode 3000 penalty of Node 1 is 0.0
#
# episode 3000 penalty of Node 2 is -4.848380811371257
#
# episode 3000 transmission discrepancy is [41.11398844779682, 12.718985073659471, 15.56219155227285, 43.136577402778435, 3.6487718097190935, 15.90836141208181, 23.398501412794186, 4.833879122379301]
#
# episode 3200 reward of Node 1 is -1.0607365456283502
#
# episode 3200 reward of Node 2 is 0.40189632197203984
#
# episode 3200 penalty of Node 1 is 0.0
#
# episode 3200 penalty of Node 2 is -2.0041554809664572
#
# episode 3200 transmission discrepancy is [0.16220819966865463, 0.17174278566216117, 0.07962830514267694, 0.9847306632835569, 0.1408941347648991, 0.4939262929338071, 0.8859468266113026, 0.33077768927883966]
#
# episode 3400 reward of Node 1 is -1.1418097417297115
#
# episode 3400 reward of Node 2 is 0.4531679990867807
#
# episode 3400 penalty of Node 1 is -1.2489590466022493
#
# episode 3400 penalty of Node 2 is -3.139473720904234
#
# episode 3400 transmission discrepancy is [0.6766110727317454, 0.34066563459684573, 0.5787547286112016, 0.5693850049331672, 0.317857086043297, 0.4853595213406834, 0.11481381344125907, 0.04499496919625301]
#
# episode 3600 reward of Node 1 is -1.2010875433919463
#
# episode 3600 reward of Node 2 is 0.5159494966252725
#
# episode 3600 penalty of Node 1 is -2.593868386745453
#
# episode 3600 penalty of Node 2 is -1.9735048334294572
#
# episode 3600 transmission discrepancy is [0.385709725115305, 0.33528014117504057, 0.05900762994517095, 0.3676638177303886, 0.65384928859973, 0.8606289143895935, 0.14331341950037313, 0.025293827502750332]
#
# episode 3800 reward of Node 1 is -1.1984948474273822
#
# episode 3800 reward of Node 2 is 0.3256241440958313
#
# episode 3800 penalty of Node 1 is -2.0403575457632543
#
# episode 3800 penalty of Node 2 is -1.0579962826414693
#
# episode 3800 transmission discrepancy is [0.8092252220837111, 0.26771629113338946, 0.3161425716357371, 0.23194724419762736, 0.14578357889956806, 0.02249837523769571, 0.05909546299122326, 0.01736575811081309]
#
# episode 4000 reward of Node 1 is -1.2006551810609902
#
# episode 4000 reward of Node 2 is 0.404397531570947
#
# episode 4000 penalty of Node 1 is -1.4889664210379125
#
# episode 4000 penalty of Node 2 is -0.8271664705742656
#
# episode 4000 transmission discrepancy is [0.12388382124572672, 0.4020063497310673, 0.062168697645311966, 0.025230796546814815, 0.0432007267132235, 0.1215005042549322, 0.0919148462536441, 0.05286045558763419]
#
# episode 4200 reward of Node 1 is -1.18646239359898
#
# episode 4200 reward of Node 2 is 0.4016669805592312
#
# episode 4200 penalty of Node 1 is -0.8992968618869782
#
# episode 4200 penalty of Node 2 is -0.5307693807875444
#
# episode 4200 transmission discrepancy is [0.03622174005020895, 0.2035186011757446, 0.0833871644309454, 0.051377949578423454, 0.013988458865767939, 0.03312965525218203, 0.016811211444512253, 0.03634462174641584]
#
# episode 4400 reward of Node 1 is -1.1688211571112892
#
# episode 4400 reward of Node 2 is 0.3930005746878711
#
# episode 4400 penalty of Node 1 is -0.4701460123062134
#
# episode 4400 penalty of Node 2 is -0.18022441457185862
#
# episode 4400 transmission discrepancy is [0.047835435244707014, 0.22922731486928427, 0.16697104344481062, 0.004311151644849076, 0.006254123770510489, 0.0010366658001998985, 0.04472612151133859, 0.03425112456836388]
#
# episode 4600 reward of Node 1 is -1.1368276309724639
#
# episode 4600 reward of Node 2 is 0.4326070774723658
#
# episode 4600 penalty of Node 1 is 0.0
#
# episode 4600 penalty of Node 2 is -5.5795687766605796e-05
#
# episode 4600 transmission discrepancy is [0.017846969377643518, 0.0243330168591811, 0.298433825652765, 0.040391081966802744, 0.03156456284292375, 0.05374129913016645, 0.07381507416031496, 0.017831047676260425]
#
# episode 4800 reward of Node 1 is -1.110389844127661
#
# episode 4800 reward of Node 2 is 0.43503593461752343
#
# episode 4800 penalty of Node 1 is 0.0
#
# episode 4800 penalty of Node 2 is -7.086029930150134e-05
#
# episode 4800 transmission discrepancy is [0.0014949421340588742, 0.30152424185189375, 0.23746880433593276, 0.016982347137940224, 0.022219922860969632, 0.03641692469707891, 0.09033920674527707, 0.002156603251862066]
#
# episode 5000 reward of Node 1 is -1.0904606156897092
#
# episode 5000 reward of Node 2 is 0.4318413789601274
#
# episode 5000 penalty of Node 1 is 0.0
#
# episode 5000 penalty of Node 2 is -5.909723796331293e-05
#
# episode 5000 transmission discrepancy is [0.0009484248301561138, 0.27524879941817915, 0.13962957573174606, 0.01359560604902299, 0.004006653507346414, 0.03944864099848644, 0.11664854008962777, 0.0014461390085642734]
#
# episode 5200 reward of Node 1 is -1.0704807495764848
#
# episode 5200 reward of Node 2 is 0.4220468671729937
#
# episode 5200 penalty of Node 1 is 0.0
#
# episode 5200 penalty of Node 2 is -6.498538331428278e-05
#
# episode 5200 transmission discrepancy is [0.0048165246990237165, 0.25061254594680094, 0.09225877179090247, 0.06400157429465025, 0.046492265382610753, 0.05883092360558351, 0.1219859118368305, 0.010855315586425718]
#
# episode 5400 reward of Node 1 is -1.0518144232611302
#
# episode 5400 reward of Node 2 is 0.4148618720907598
#
# episode 5400 penalty of Node 1 is 0.0
#
# episode 5400 penalty of Node 2 is -6.498064224679682e-05
#
# episode 5400 transmission discrepancy is [0.012227923147051456, 0.22668137784510378, 0.06511236763616068, 0.06580349276406139, 0.07887817277244835, 0.048775489238757075, 0.13527806879989157, 0.01704953026449374]
#
# episode 5600 reward of Node 1 is -1.034349303961574
#
# episode 5600 reward of Node 2 is 0.4019727032824445
#
# episode 5600 penalty of Node 1 is 0.0
#
# episode 5600 penalty of Node 2 is -5.7251381091425206e-05
#
# episode 5600 transmission discrepancy is [0.03673326403094279, 0.16920627399134958, 0.07644862498197114, 0.05270683351781713, 0.09845393949940018, 0.028853471210787518, 0.09327852860982944, 0.016832875072154252]
#
# episode 5800 reward of Node 1 is -1.0178084612395006
#
# episode 5800 reward of Node 2 is 0.40036193927846986
#
# episode 5800 penalty of Node 1 is 0.0
#
# episode 5800 penalty of Node 2 is -6.164369641163176e-05
#
# episode 5800 transmission discrepancy is [0.051505561018316826, 0.18015534599632588, 0.059885066905344786, 0.046036304720104226, 0.08886122494365623, 0.040590971155971545, 0.13052365277295053, 0.018878836603647642]
#
# episode 6000 reward of Node 1 is -1.0019141015599908
#
# episode 6000 reward of Node 2 is 0.39571517595607675
#
# episode 6000 penalty of Node 1 is 0.0
#
# episode 6000 penalty of Node 2 is -5.0030363444420806e-05
#
# episode 6000 transmission discrepancy is [0.02395685901099398, 0.1216400768427377, 0.08140832745039006, 0.04531829054208458, 0.08397683590273175, 0.019070435306474565, 0.10600090876867796, 0.018931900620117403]
#
# episode 6200 reward of Node 1 is -0.9860764394800502
#
# episode 6200 reward of Node 2 is 0.40234184110026056
#
# episode 6200 penalty of Node 1 is 0.0
#
# episode 6200 penalty of Node 2 is -4.5693537349219324e-05
#
# episode 6200 transmission discrepancy is [0.03144506637825373, 0.10628482131269834, 0.05468253312721316, 0.016398198770836814, 0.06801052539728403, 0.06325187873736127, 0.09953991098957005, 0.01732243877897588]
#
# episode 6400 reward of Node 1 is -0.9684361935293307
#
# episode 6400 reward of Node 2 is 0.39313191658561
#
# episode 6400 penalty of Node 1 is 0.0
#
# episode 6400 penalty of Node 2 is -3.532335162414526e-05
#
# episode 6400 transmission discrepancy is [0.05699786083489755, 0.020395840484937366, 0.09602465871421373, 0.008261952080054868, 0.04280393875885835, 0.012117053071833084, 0.11071252116522601, 0.005919691131431648]
#
# episode 6600 reward of Node 1 is -0.9499249094614212
#
# episode 6600 reward of Node 2 is 0.40425062381641735
#
# episode 6600 penalty of Node 1 is 0.0
#
# episode 6600 penalty of Node 2 is -3.219036467303696e-05
#
# episode 6600 transmission discrepancy is [0.015896727415920964, 0.02496783119671875, 0.051574235770573296, 0.004692198413302151, 0.05227045876120684, 0.07879681639926162, 0.09111011620367293, 0.002595262569712986]
#
# episode 6800 reward of Node 1 is -0.9291117921857343
#
# episode 6800 reward of Node 2 is 0.39697478793300695
#
# episode 6800 penalty of Node 1 is 0.0
#
# episode 6800 penalty of Node 2 is -4.57144310397041e-05
#
# episode 6800 transmission discrepancy is [0.11613624264367672, 0.08028760778263688, 0.06550110274203291, 0.016570146075025605, 0.057060382883825866, 0.0013829984138382656, 0.10179192949141225, 0.01841390036459245]
#
# episode 7000 reward of Node 1 is -0.9103306354407088
#
# episode 7000 reward of Node 2 is 0.39335711867889556
#
# episode 7000 penalty of Node 1 is 0.0
#
# episode 7000 penalty of Node 2 is -4.5910065537314534e-05
#
# episode 7000 transmission discrepancy is [0.14032358097745146, 0.07811954953000111, 0.09456004384469452, 0.001516871842142109, 0.04868432678015111, 0.013148045629137073, 0.07494613176759657, 0.007802105001971427]
#
# episode 7200 reward of Node 1 is -0.8933785960878822
#
# episode 7200 reward of Node 2 is 0.3959185030157507
#
# episode 7200 penalty of Node 1 is 0.0
#
# episode 7200 penalty of Node 2 is -3.86857106744138e-05
#
# episode 7200 transmission discrepancy is [0.09533188616032362, 0.04740965568164057, 0.04556099479539455, 0.014084929020739878, 0.0560369108829093, 0.045668495017224586, 0.0776725461960126, 0.005091688989892873]
#
# episode 7400 reward of Node 1 is -0.8828598339958516
#
# episode 7400 reward of Node 2 is 0.39379119848559113
#
# episode 7400 penalty of Node 1 is 0.0
#
# episode 7400 penalty of Node 2 is -3.79560012362397e-05
#
# episode 7400 transmission discrepancy is [0.07264527471144078, 0.06570078864605478, 0.026524886744397236, 0.022485861330039825, 0.049066904381305676, 0.06846166543365229, 0.06689150704524138, 0.007783124070265046]
#
# episode 7600 reward of Node 1 is -0.8762910499704946
#
# episode 7600 reward of Node 2 is 0.39293832075799245
#
# episode 7600 penalty of Node 1 is 0.0
#
# episode 7600 penalty of Node 2 is -3.476897209399788e-05
#
# episode 7600 transmission discrepancy is [0.05025892568778545, 0.10219928421147273, 0.03330127047983922, 0.007090911904924724, 0.05193712591464461, 0.02887434097411301, 0.07152882994174803, 0.0024990318254509702]
#
# episode 7800 reward of Node 1 is -0.873163231151858
#
# episode 7800 reward of Node 2 is 0.3924624728680371
#
# episode 7800 penalty of Node 1 is 0.0
#
# episode 7800 penalty of Node 2 is -3.6006564475240314e-05
#
# episode 7800 transmission discrepancy is [0.01900011153082204, 0.10441777000670527, 0.02573948098455503, 0.0030107329016146878, 0.057925529992033375, 0.04965568452308844, 0.08360568830882897, 0.01671064650475529]
#
# episode 8000 reward of Node 1 is -0.8710914649692312
#
# episode 8000 reward of Node 2 is 0.3904781667391579
#
# episode 8000 penalty of Node 1 is 0.0
#
# episode 8000 penalty of Node 2 is -3.1189353658022866e-05
#
# episode 8000 transmission discrepancy is [0.008015621178628862, 0.11180001623030478, 0.009503872768590327, 0.0036691247289013518, 0.03835680231046723, 0.07524091654435239, 0.05378964630155991, 0.011517536517423821]
#
# episode 8200 reward of Node 1 is -0.8690041016503065
#
# episode 8200 reward of Node 2 is 0.39113394551445313
#
# episode 8200 penalty of Node 1 is 0.0
#
# episode 8200 penalty of Node 2 is -2.5309795565955542e-05
#
# episode 8200 transmission discrepancy is [0.0006549322189641771, 0.1318066077344895, 0.010079819651892308, 0.0004959304283858046, 0.03197029637036053, 0.06198869948482866, 0.013396974697968744, 0.002704695072665686]
#
# episode 8400 reward of Node 1 is -0.8663675351733084
#
# episode 8400 reward of Node 2 is 0.391126978747873
#
# episode 8400 penalty of Node 1 is 0.0
#
# episode 8400 penalty of Node 2 is -2.7470424207254498e-05
#
# episode 8400 transmission discrepancy is [0.01996597123773114, 0.17249225105748422, 0.014704989946764613, 0.0008531402473010985, 0.00402582377484606, 0.02002786104339549, 0.035311808132988176, 0.007322396632034156]
#
# episode 8600 reward of Node 1 is -0.8660643235303954
#
# episode 8600 reward of Node 2 is 0.3894851133792403
#
# episode 8600 penalty of Node 1 is 0.0
#
# episode 8600 penalty of Node 2 is -2.8707366885820205e-05
#
# episode 8600 transmission discrepancy is [0.015647111397242952, 0.12375045435952359, 0.0030412664680739, 0.00022507786680137087, 0.046258227094316595, 0.03288280922921416, 0.05154390114811491, 0.013724821294914591]
#
# episode 8800 reward of Node 1 is -0.865816397733239
#
# episode 8800 reward of Node 2 is 0.39392347506225966
#
# episode 8800 penalty of Node 1 is 0.0
#
# episode 8800 penalty of Node 2 is -2.0974866954615834e-05
#
# episode 8800 transmission discrepancy is [0.019283347294127395, 0.08673422742224801, 0.0043031427867674665, 0.002707179642158053, 0.026072366639844802, 0.03697099095757039, 0.032747477070856235, 0.0009299377325859837]
#
# episode 9000 reward of Node 1 is -0.864938796240099
#
# episode 9000 reward of Node 2 is 0.39141544486837143
#
# episode 9000 penalty of Node 1 is 0.0
#
# episode 9000 penalty of Node 2 is -2.199697726234895e-05
#
# episode 9000 transmission discrepancy is [0.004217206384922179, 0.052435597133779765, 0.007901536878790694, 0.006092200148408722, 0.028038189555598336, 0.05891650696299422, 0.05311018805831225, 0.009258347500683328]
#
# episode 9200 reward of Node 1 is -0.863954209105429
#
# episode 9200 reward of Node 2 is 0.38915866934631277
#
# episode 9200 penalty of Node 1 is 0.0
#
# episode 9200 penalty of Node 2 is -2.063422479678039e-05
#
# episode 9200 transmission discrepancy is [0.002653797423818105, 0.06326622529180526, 0.008747492239947974, 0.009242222566342662, 0.03198370408782836, 0.036604145371327945, 0.044999495904392006, 0.008845165082341566]
#
# episode 9400 reward of Node 1 is -0.8619416370506963
#
# episode 9400 reward of Node 2 is 0.39018856714569217
#
# episode 9400 penalty of Node 1 is 0.0
#
# episode 9400 penalty of Node 2 is -2.1880757796064998e-05
#
# episode 9400 transmission discrepancy is [0.007877743518413638, 0.06072865062824917, 0.011894886322423304, 0.005638853557776713, 0.038802371239153644, 0.04173297528317477, 0.044641907112456636, 0.0074901902990021085]
#
# episode 9600 reward of Node 1 is -0.8614713968607688
#
# episode 9600 reward of Node 2 is 0.3899916553598051
#
# episode 9600 penalty of Node 1 is 0.0
#
# episode 9600 penalty of Node 2 is -1.9162688360058414e-05
#
# episode 9600 transmission discrepancy is [0.010807239501829713, 0.024676218332999156, 0.022249587516199654, 0.002288254750276053, 0.04466836250684736, 0.03597324734052876, 0.047694910920249356, 0.00326906273165406]
#
# episode 9800 reward of Node 1 is -0.8613915709970561
#
# episode 9800 reward of Node 2 is 0.3912706165953109
#
# episode 9800 penalty of Node 1 is 0.0
#
# episode 9800 penalty of Node 2 is -1.9398007545734687e-05
#
# episode 9800 transmission discrepancy is [0.002286522093790211, 0.00603864407558774, 0.03466858301366926, 0.022097317539063965, 0.041965491165626645, 0.032630474400114906, 0.046196180674954235, 0.008096862494539891]
#
# episode 10000 reward of Node 1 is -0.8613648544584223
#
# episode 10000 reward of Node 2 is 0.38843784900814243
#
# episode 10000 penalty of Node 1 is 0.0
#
# episode 10000 penalty of Node 2 is -1.717588805145951e-05
#
# episode 10000 transmission discrepancy is [0.00891386288579099, 0.015303755236942607, 0.020567557879687115, 0.0059963057308962675, 0.05824229853460139, 0.025237935109686305, 0.03417131791274386, 0.0033258472242465587]
#
# episode 10200 reward of Node 1 is -0.8624879744134522
#
# episode 10200 reward of Node 2 is 0.3877722707343525
#
# episode 10200 penalty of Node 1 is 0.0
#
# episode 10200 penalty of Node 2 is -0.003317022322731955
#
# episode 10200 transmission discrepancy is [0.005466110277637881, 0.04093152623048013, 0.002698220607541657, 0.012523849988568259, 0.04620411815353265, 0.044892534819375385, 0.04474330533579263, 0.0005469557664810054]
#
# episode 10400 reward of Node 1 is -0.8627568064411267
#
# episode 10400 reward of Node 2 is 0.39205864038157867
#
# episode 10400 penalty of Node 1 is 0.0
#
# episode 10400 penalty of Node 2 is -2.5689242504778774e-05
#
# episode 10400 transmission discrepancy is [0.04676664376238193, 0.030234740259096782, 0.019428917879650953, 0.008652138755770977, 0.05258671643921531, 0.062429702723555636, 0.021509857071229987, 0.015283708156886178]
#
# episode 10600 reward of Node 1 is -0.8620899244533115
#
# episode 10600 reward of Node 2 is 0.3879403138411125
#
# episode 10600 penalty of Node 1 is 0.0
#
# episode 10600 penalty of Node 2 is -1.3681368849614016e-05
#
# episode 10600 transmission discrepancy is [0.004362179282296097, 0.023021632524915958, 0.003642427083775601, 0.0039501238378392145, 0.05545733813420384, 0.0030704061689874607, 0.03227515869571107, 0.011034422768410934]
#
# episode 10800 reward of Node 1 is -0.8615123226432209
#
# episode 10800 reward of Node 2 is 0.3912501760683901
#
# episode 10800 penalty of Node 1 is 0.0
#
# episode 10800 penalty of Node 2 is -1.6860910369228323e-05
#
# episode 10800 transmission discrepancy is [0.00018342519663860912, 0.0440221202515545, 0.01568466986255146, 0.028278733196373196, 0.04295235909768991, 0.016604354504664798, 0.013070657771635297, 0.00781278381117545]
#
# episode 11000 reward of Node 1 is -0.8612769087912818
#
# episode 11000 reward of Node 2 is 0.38715014651305135
#
# episode 11000 penalty of Node 1 is 0.0
#
# episode 11000 penalty of Node 2 is -2.541720772732106e-05
#
# episode 11000 transmission discrepancy is [0.0017579044716597991, 0.03143052922078482, 0.010588486960713794, 0.0042548663513031215, 0.0469396651498144, 0.052831056844048874, 0.07737083787529997, 0.02899873039958578]
#
# episode 11200 reward of Node 1 is -0.8606464860609776
#
# episode 11200 reward of Node 2 is 0.3907459373040776
#
# episode 11200 penalty of Node 1 is 0.0
#
# episode 11200 penalty of Node 2 is -1.7538351239428354e-05
#
# episode 11200 transmission discrepancy is [0.004622833921338554, 0.012345912900578071, 1.3862407030273971e-05, 0.03535075397176968, 0.033361493104273165, 0.03137313279265186, 0.04600957962421859, 0.012305943672423325]
#
# episode 11400 reward of Node 1 is -0.8603472674841525
#
# episode 11400 reward of Node 2 is 0.3942505937398757
#
# episode 11400 penalty of Node 1 is 0.0
#
# episode 11400 penalty of Node 2 is -2.5827072494460168e-05
#
# episode 11400 transmission discrepancy is [0.022003244647592624, 0.05258653073417463, 0.006671179342404798, 0.048830324943423875, 0.0415945303137093, 0.011401815841026064, 0.04891381052419064, 0.026269288598079754]
#
# episode 11600 reward of Node 1 is -0.8613111897922084
#
# episode 11600 reward of Node 2 is 0.3996037804978283
#
# episode 11600 penalty of Node 1 is 0.0
#
# episode 11600 penalty of Node 2 is -2.322816103406176e-05
#
# episode 11600 transmission discrepancy is [0.008826743582432073, 0.05846768472234487, 0.0038355372038267888, 0.063805612648828, 0.02881228026371474, 0.023860745322878074, 0.032535420526325964, 0.012137586070267048]
#
# episode 11800 reward of Node 1 is -0.8616707690287109
#
# episode 11800 reward of Node 2 is 0.40254055565001245
#
# episode 11800 penalty of Node 1 is 0.0
#
# episode 11800 penalty of Node 2 is -2.0430415522421798e-05
#
# episode 11800 transmission discrepancy is [0.006484678647510123, 0.03539051604321486, 0.006929997608352778, 0.029424806564861683, 0.04304103350789035, 0.02966147995450541, 0.0400566143997132, 0.013315028498169568]
#
# episode 12000 reward of Node 1 is -0.8607803366538903
#
# episode 12000 reward of Node 2 is 0.4034617722077797
#
# episode 12000 penalty of Node 1 is 0.0
#
# episode 12000 penalty of Node 2 is -2.1313180167246415e-05
#
# episode 12000 transmission discrepancy is [0.007065229740554457, 0.03589598286806961, 0.013386078586520966, 0.03260947320652008, 0.045641783262816205, 0.012902644162686272, 0.05330628303752505, 0.012324326807771513]
#
# episode 12200 reward of Node 1 is -0.8581511611023137
#
# episode 12200 reward of Node 2 is 0.4084286402720311
#
# episode 12200 penalty of Node 1 is 0.0
#
# episode 12200 penalty of Node 2 is -2.077149461644794e-05
#
# episode 12200 transmission discrepancy is [0.008256707468589752, 0.028059855351528995, 0.046678948801258, 0.01607804068380858, 0.04279586555782089, 0.014059516548186934, 0.0376038496532729, 0.014182162100013329]
#
# episode 12400 reward of Node 1 is -0.8567800442660413
#
# episode 12400 reward of Node 2 is 0.410355866701424
#
# episode 12400 penalty of Node 1 is 0.0
#
# episode 12400 penalty of Node 2 is -1.895219560347741e-05
#
# episode 12400 transmission discrepancy is [0.010592855646443411, 0.02734251714956315, 0.04152392974636143, 0.013555106176823983, 0.046085408956670904, 0.006315855307406082, 0.03538763086262975, 0.008718652188875353]
#
# episode 12600 reward of Node 1 is -0.8558666307248886
#
# episode 12600 reward of Node 2 is 0.41299894930083586
#
# episode 12600 penalty of Node 1 is 0.0
#
# episode 12600 penalty of Node 2 is -1.7181439696838296e-05
#
# episode 12600 transmission discrepancy is [0.006651582918308918, 0.022870440030494876, 0.028436673005131752, 0.0033961089598761873, 0.04909167318338348, 0.004284299089974297, 0.040382116887276, 0.01670150289393746]
#
# episode 12800 reward of Node 1 is -0.8568170535516877
#
# episode 12800 reward of Node 2 is 0.4153790420847189
#
# episode 12800 penalty of Node 1 is 0.0
#
# episode 12800 penalty of Node 2 is -1.2868141725194705e-05
#
# episode 12800 transmission discrepancy is [0.002154646044793651, 0.0299962879051634, 0.012857175685155653, 0.0030016320370691574, 0.04567648941264224, 0.01349865017476759, 0.013663633472553727, 0.007832902519801621]
#
# episode 13000 reward of Node 1 is -0.8560224263637232
#
# episode 13000 reward of Node 2 is 0.4179735271094931
#
# episode 13000 penalty of Node 1 is 0.0
#
# episode 13000 penalty of Node 2 is -1.4372513127838716e-05
#
# episode 13000 transmission discrepancy is [0.001714233242445573, 0.02931061909701782, 0.0003407756213960056, 0.00037941433213006803, 0.05566638784017641, 0.00305001206561073, 0.03374759774366609, 0.019516091335944452]
#
# episode 13200 reward of Node 1 is -0.8592225654808359
#
# episode 13200 reward of Node 2 is 0.42109023479366375
#
# episode 13200 penalty of Node 1 is 0.0
#
# episode 13200 penalty of Node 2 is -1.581479221787774e-05
#
# episode 13200 transmission discrepancy is [0.006171260060270356, 0.029952314654323686, 0.0016381110494592122, 0.00189231913273602, 0.046555460486111144, 0.02373238098640229, 0.04084669938477248, 0.007359376424702191]
#
# episode 13400 reward of Node 1 is -0.8570759185336245
#
# episode 13400 reward of Node 2 is 0.4208953776739184
#
# episode 13400 penalty of Node 1 is 0.0
#
# episode 13400 penalty of Node 2 is -1.2862210383638128e-05
#
# episode 13400 transmission discrepancy is [0.005854122917583027, 0.030828505078154933, 0.003605634426605775, 0.01097099606722196, 0.04323210038458569, 0.010938668251625927, 0.01600785522039061, 0.0071842214902133605]
#
# episode 13600 reward of Node 1 is -0.8612001444152929
#
# episode 13600 reward of Node 2 is 0.42330232086446096
#
# episode 13600 penalty of Node 1 is 0.0
#
# episode 13600 penalty of Node 2 is -9.098347093959092e-06
#
# episode 13600 transmission discrepancy is [0.0024984937617062997, 0.03081785401423076, 1.7345869025575666e-06, 0.0009750376189572307, 0.019473100053247094, 0.011145714362150727, 0.010845269969635751, 0.015226266572760494]
#
# episode 13800 reward of Node 1 is -0.8604625402092072
#
# episode 13800 reward of Node 2 is 0.42453337813696707
#
# episode 13800 penalty of Node 1 is 0.0
#
# episode 13800 penalty of Node 2 is -1.028977433240925e-05
#
# episode 13800 transmission discrepancy is [0.0006636477010601993, 0.029511852870314215, 0.0013891403187358264, 0.006108567293452438, 0.00829785841848718, 0.026047872230730462, 0.00836888879667086, 0.022509915694641336]
#
# episode 14000 reward of Node 1 is -0.8566793832706431
#
# episode 14000 reward of Node 2 is 0.42548373570422343
#
# episode 14000 penalty of Node 1 is 0.0
#
# episode 14000 penalty of Node 2 is -8.983125196983011e-06
#
# episode 14000 transmission discrepancy is [0.003527026151203927, 0.030410634174572237, 0.004780843392538259, 0.015021726784432587, 0.008866238557409645, 0.015542800765672382, 0.0074298433302395495, 0.004252138813761519]
#
# episode 14200 reward of Node 1 is -0.8568808962135768
#
# episode 14200 reward of Node 2 is 0.4270996508665895
#
# episode 14200 penalty of Node 1 is 0.0
#
# episode 14200 penalty of Node 2 is -9.268754622324592e-06
#
# episode 14200 transmission discrepancy is [0.0015299721912782616, 0.027613610444291226, 0.002219137451561437, 0.012445955106173301, 0.0030267869406017667, 0.004018226491034227, 0.02746527612169558, 0.014368581476610132]
#
# episode 14400 reward of Node 1 is -0.8552743764086619
#
# episode 14400 reward of Node 2 is 0.4283847283850641
#
# episode 14400 penalty of Node 1 is 0.0
#
# episode 14400 penalty of Node 2 is -6.336208486160544e-06
#
# episode 14400 transmission discrepancy is [0.0026984987105791447, 0.027218589213191535, 0.0029272059749416712, 0.0010106209502538377, 0.01043853193642974, 0.0006173443986661198, 0.01585409834453344, 0.0025971953330099495]
#
# episode 14600 reward of Node 1 is -0.8550342323929065
#
# episode 14600 reward of Node 2 is 0.4279532124752384
#
# episode 14600 penalty of Node 1 is 0.0
#
# episode 14600 penalty of Node 2 is -8.146178797062476e-06
#
# episode 14600 transmission discrepancy is [0.00220566222493801, 0.026088898972766117, 0.00307560189325784, 0.019490055058078326, 0.009185545572876208, 0.0012827448477921166, 0.006843775848302869, 0.013289503552613269]
#
# episode 14800 reward of Node 1 is -0.8678415132873435
#
# episode 14800 reward of Node 2 is 0.4275783697894071
#
# episode 14800 penalty of Node 1 is 0.0
#
# episode 14800 penalty of Node 2 is -6.854257738128666e-06
#
# episode 14800 transmission discrepancy is [0.002028898336526197, 0.01936800615911949, 0.00285884934029923, 0.017869943736791072, 0.009166161830457042, 0.0015432924243086177, 0.011357090653270063, 0.004350334900514952]
#
# episode 15000 reward of Node 1 is -0.8563446865776116
#
# episode 15000 reward of Node 2 is 0.42591416905997037
#
# episode 15000 penalty of Node 1 is 0.0
#
# episode 15000 penalty of Node 2 is -1.2679099744742927e-05
#
# episode 15000 transmission discrepancy is [0.0013885930842860716, 0.02676844005687684, 0.002351031032276296, 0.020697171913980128, 0.015420032566218822, 0.021344703358835204, 0.0277771129552562, 0.011043912479699713]
#
# episode 15200 reward of Node 1 is -0.8565830589369124
#
# episode 15200 reward of Node 2 is 0.4263693121270762
#
# episode 15200 penalty of Node 1 is 0.0
#
# episode 15200 penalty of Node 2 is -5.134152609334919e-06
#
# episode 15200 transmission discrepancy is [1.6984158321520226e-05, 0.020938007686169158, 0.001074944033518932, 0.012500200983183163, 0.0016748505815797898, 0.0051845849555647305, 0.00989195108854446, 6.000260646743527e-05]
#
# episode 15400 reward of Node 1 is -0.8593782699592091
#
# episode 15400 reward of Node 2 is 0.42784298540607746
#
# episode 15400 penalty of Node 1 is 0.0
#
# episode 15400 penalty of Node 2 is -1.0189606686757459e-05
#
# episode 15400 transmission discrepancy is [0.00032392064675690335, 0.018929288427500524, 0.0062781018875455175, 0.01136023100379191, 0.013491196565901475, 0.03230549259914994, 0.014135383039999283, 0.00507245269692902]
#
# episode 15600 reward of Node 1 is -0.8592203989482001
#
# episode 15600 reward of Node 2 is 0.42908948149073967
#
# episode 15600 penalty of Node 1 is 0.0
#
# episode 15600 penalty of Node 2 is -6.001105933605545e-06
#
# episode 15600 transmission discrepancy is [0.0007107396615566586, 0.01201885166292982, 0.000780571016690601, 0.013901003461057826, 0.0063383634958711355, 0.0009902061971516218, 0.013884486151226838, 0.011386837689570939]
#
# episode 15800 reward of Node 1 is -0.8564327115030095
#
# episode 15800 reward of Node 2 is 0.42703957596325814
#
# episode 15800 penalty of Node 1 is 0.0
#
# episode 15800 penalty of Node 2 is -4.525043511588223e-06
#
# episode 15800 transmission discrepancy is [0.0011097722118407205, 0.013062474654731204, 0.00010430795815352667, 0.005536237106191777, 0.002490912134121004, 0.0024102064022244463, 0.007331386257376948, 0.013205138391242599]
#
# episode 16000 reward of Node 1 is -0.859218794062792
#
# episode 16000 reward of Node 2 is 0.42837100342746465
#
# episode 16000 penalty of Node 1 is 0.0
#
# episode 16000 penalty of Node 2 is -6.966523634874023e-06
#
# episode 16000 transmission discrepancy is [0.0007846172874437229, 0.008732191772850229, 0.004580794527257126, 0.007956495838072897, 0.004587430023995864, 0.00665583500320821, 0.01794716446596567, 0.018420707429946503]
#
# episode 16200 reward of Node 1 is -0.8568134666775364
#
# episode 16200 reward of Node 2 is 0.4290570109169247
#
# episode 16200 penalty of Node 1 is 0.0
#
# episode 16200 penalty of Node 2 is -5.456720004332638e-06
#
# episode 16200 transmission discrepancy is [0.0006191320149966373, 0.013729693299254109, 0.002620080804490499, 0.003389084470427406, 0.012474272371790107, 0.005818164216602639, 0.00048175333252231667, 0.015435019533242667]
#
# episode 16400 reward of Node 1 is -0.8593948159221296
#
# episode 16400 reward of Node 2 is 0.4265345010781348
#
# episode 16400 penalty of Node 1 is 0.0
#
# episode 16400 penalty of Node 2 is -5.1095543035213345e-06
#
# episode 16400 transmission discrepancy is [0.00035973833706037794, 0.009296831034546926, 0.000757254690952891, 0.007770442921888332, 0.00170021328986536, 0.021973574331518364, 6.017267445557195e-05, 0.00917731575492553]
#
# episode 16600 reward of Node 1 is -0.8564843167246146
#
# episode 16600 reward of Node 2 is 0.4283244161335313
#
# episode 16600 penalty of Node 1 is 0.0
#
# episode 16600 penalty of Node 2 is -5.634801940716373e-06
#
# episode 16600 transmission discrepancy is [0.0007030330737407553, 0.006059490917877497, 0.007176987542464985, 0.01102088960516312, 0.005765578871624655, 0.007939286264331713, 0.010427400217221106, 0.007255352914739888]
#
# episode 16800 reward of Node 1 is -0.8568741642660977
#
# episode 16800 reward of Node 2 is 0.42893026661426437
#
# episode 16800 penalty of Node 1 is 0.0
#
# episode 16800 penalty of Node 2 is -2.52723834883426e-06
#
# episode 16800 transmission discrepancy is [0.0003879119633793948, 0.006968308143882496, 0.000526875423915385, 0.0023755760171084717, 0.006450733718281754, 0.002194130336548028, 0.0010050289727985273, 0.005363818912428542]
#
# episode 17000 reward of Node 1 is -0.8592890252117015
#
# episode 17000 reward of Node 2 is 0.42751914054232726
#
# episode 17000 penalty of Node 1 is 0.0
#
# episode 17000 penalty of Node 2 is -4.830440096754174e-06
#
# episode 17000 transmission discrepancy is [0.0009398053963636244, 0.005640946300843552, 0.0002558128624485789, 0.006369588317937769, 0.005444399010158918, 0.012079874321578643, 0.0045781589392071, 0.012995815819003553]
#
# episode 17200 reward of Node 1 is -0.8623114382870747
#
# episode 17200 reward of Node 2 is 0.4269734015219075
#
# episode 17200 penalty of Node 1 is 0.0
#
# episode 17200 penalty of Node 2 is -6.445161707353364e-06
#
# episode 17200 transmission discrepancy is [0.0006866704105021881, 0.007297846208587089, 0.00630264384091106, 0.007095390817653424, 0.013447423965750716, 0.01572773250859072, 0.0032481825008687792, 0.010645726820669665]
#
# episode 17400 reward of Node 1 is -0.8577506462396137
#
# episode 17400 reward of Node 2 is 0.42940242410695517
#
# episode 17400 penalty of Node 1 is 0.0
#
# episode 17400 penalty of Node 2 is -6.664247461916517e-06
#
# episode 17400 transmission discrepancy is [0.0015032733334408022, 0.003761985740808882, 0.007184616751317208, 0.010815286553196302, 0.024001843563411285, 0.0023902287224828456, 0.014404836644146712, 0.0025804033103611346]
#
# episode 17600 reward of Node 1 is -0.8573087823078593
#
# episode 17600 reward of Node 2 is 0.42907527674940216
#
# episode 17600 penalty of Node 1 is 0.0
#
# episode 17600 penalty of Node 2 is -6.604431576385039e-06
#
# episode 17600 transmission discrepancy is [0.0019220972538747105, 5.498341437260024e-05, 0.007617901768767865, 0.010516846392093271, 0.010890189489551005, 0.021129969134140225, 0.006632628948551655, 0.007279699362499059]
#
# episode 17800 reward of Node 1 is -0.8565393827140544
#
# episode 17800 reward of Node 2 is 0.42939507585194686
#
# episode 17800 penalty of Node 1 is 0.0
#
# episode 17800 penalty of Node 2 is -4.30921221830154e-06
#
# episode 17800 transmission discrepancy is [0.0005080877626681968, 0.0028855836117003264, 0.006298655658355301, 0.011695257655340185, 0.0037867951696028967, 0.009073061600769705, 0.0036007080535753744, 0.005243972671003405]
#
# episode 18000 reward of Node 1 is -0.8575577595245557
#
# episode 18000 reward of Node 2 is 0.42634728177476394
#
# episode 18000 penalty of Node 1 is 0.0
#
# episode 18000 penalty of Node 2 is -6.661898758012442e-06
#
# episode 18000 transmission discrepancy is [0.0022079077141583525, 0.002669511213497344, 0.006993636976787343, 0.008679075455575003, 0.012799001243244845, 0.027506587839418728, 0.0002819355825600667, 0.005481331554882729]
#
# episode 18200 reward of Node 1 is -0.8564957438933115
#
# episode 18200 reward of Node 2 is 0.4262341000434698
#
# episode 18200 penalty of Node 1 is 0.0
#
# episode 18200 penalty of Node 2 is -2.6897165042466755e-06
#
# episode 18200 transmission discrepancy is [0.0017153233505950993, 0.0012854634577479374, 0.006088237727979617, 0.002314458350504367, 0.002364174630031357, 0.0050795504806373515, 0.004570031379298456, 0.0034799256656725674]
#
# episode 18400 reward of Node 1 is -0.8582306874547254
#
# episode 18400 reward of Node 2 is 0.42868634487664425
#
# episode 18400 penalty of Node 1 is 0.0
#
# episode 18400 penalty of Node 2 is -9.997841947200927e-06
#
# episode 18400 transmission discrepancy is [0.0011892191651980966, 0.003187184859939407, 0.005335066584962078, 0.022384470944288637, 0.013431356713937248, 0.028280690980331258, 0.018369520719204502, 0.007800909504148024]
#
# episode 18600 reward of Node 1 is -0.8578431326961955
#
# episode 18600 reward of Node 2 is 0.4272243825374754
#
# episode 18600 penalty of Node 1 is 0.0
#
# episode 18600 penalty of Node 2 is -8.104404639096075e-06
#
# episode 18600 transmission discrepancy is [0.001678759477300673, 0.005572466821263333, 0.006095802455348576, 0.025501451910777462, 0.01168098873553447, 0.02857715386257098, 0.0003078789478472288, 0.001629544180318021]
#
# episode 18800 reward of Node 1 is -0.8624613034312958
#
# episode 18800 reward of Node 2 is 0.43221040365236346
#
# episode 18800 penalty of Node 1 is 0.0
#
# episode 18800 penalty of Node 2 is -0.008697505602175803
#
# episode 18800 transmission discrepancy is [0.0014730788322552257, 0.0008511983006940227, 0.0004180893376712902, 0.029235133266716673, 0.02580449774148974, 0.0053631116028967085, 0.007131361561800276, 0.0064042485613313715]
#
# episode 19000 reward of Node 1 is -0.8589712385204042
#
# episode 19000 reward of Node 2 is 0.4294588186899879
#
# episode 19000 penalty of Node 1 is 0.0
#
# episode 19000 penalty of Node 2 is -6.095241408493379e-06
#
# episode 19000 transmission discrepancy is [0.0005246713449338358, 0.0003290483778783937, 7.964488830225491e-06, 0.020575404590779556, 0.025595559063695816, 2.0297941777158712e-05, 0.00027709469875247805, 0.013622373578286329]
#
# episode 19200 reward of Node 1 is -0.858540456795497
#
# episode 19200 reward of Node 2 is 0.429443812196892
#
# episode 19200 penalty of Node 1 is 0.0
#
# episode 19200 penalty of Node 2 is -4.563724254822433e-06
#
# episode 19200 transmission discrepancy is [0.0005826704008882189, 0.0017535962699355423, 0.003378412774182493, 0.013235053180693512, 0.011542624070692398, 0.013057654752195447, 0.001655481991861052, 0.00043174910777565856]
#
# episode 19400 reward of Node 1 is -0.8583030985713033
#
# episode 19400 reward of Node 2 is 0.430177553249932
#
# episode 19400 penalty of Node 1 is 0.0
#
# episode 19400 penalty of Node 2 is -6.352563983598359e-06
#
# episode 19400 transmission discrepancy is [0.0012820855136226328, 0.00020355477897737728, 0.005731913236033392, 0.004148501991721787, 0.016314786611076215, 0.023435804322090803, 0.001931540431481693, 0.010477452950979682]
#
# episode 19600 reward of Node 1 is -0.8597385523841647
#
# episode 19600 reward of Node 2 is 0.4287884089273166
#
# episode 19600 penalty of Node 1 is 0.0
#
# episode 19600 penalty of Node 2 is -4.618381200790722e-06
#
# episode 19600 transmission discrepancy is [0.00020313239203062494, 0.0008322124831323663, 0.003147211779307213, 0.009236416630500344, 0.01582872118008538, 0.007377386050691825, 0.007369493091939461, 0.002189238400220006]
#
# episode 19800 reward of Node 1 is -0.8631334047409536
#
# episode 19800 reward of Node 2 is 0.4314679197302628
#
# episode 19800 penalty of Node 1 is 0.0
#
# episode 19800 penalty of Node 2 is -5.5143655996253936e-06
#
# episode 19800 transmission discrepancy is [0.0018894938183109389, 0.002032211214739732, 0.000707652375666612, 0.0052588148561483194, 0.010110980395062086, 0.02521567911318101, 0.004661962574061818, 0.00526686164908341]
#
# episode 20000 reward of Node 1 is -0.858944935597364
#
# episode 20000 reward of Node 2 is 0.4319586395566968
#
# episode 20000 penalty of Node 1 is 0.0
#
# episode 20000 penalty of Node 2 is -3.6110548522785283e-06
#
# episode 20000 transmission discrepancy is [0.00288172366868622, 0.00010612062229142794, 0.006224551598904782, 0.00558982456281143, 0.008821082429044225, 0.00735426183259591, 0.0016245459409418572, 0.0035084378675094285]
#
# episode 20200 reward of Node 1 is -0.8596068441767679
#
# episode 20200 reward of Node 2 is 0.42397671510055246
#
# episode 20200 penalty of Node 1 is 0.0
#
# episode 20200 penalty of Node 2 is -8.521554048869719e-06
#
# episode 20200 transmission discrepancy is [0.0018064988063812848, 0.0012037338163111144, 0.005675605001499662, 0.009737436612240913, 0.021294208410530757, 0.034187177938711955, 0.007554527488011331, 0.0037563524150101557]
#
# episode 20400 reward of Node 1 is -0.85847905881244
#
# episode 20400 reward of Node 2 is 0.4305109894624749
#
# episode 20400 penalty of Node 1 is 0.0
#
# episode 20400 penalty of Node 2 is -9.124889529934067e-06
#
# episode 20400 transmission discrepancy is [0.0011274841891193432, 0.00205533386940715, 0.03434659772185, 3.0728954541814346e-05, 0.01241384171549953, 0.009752834430376112, 0.012686813329779056, 0.018835261088767652]
#
# episode 20600 reward of Node 1 is -0.8646087904466682
#
# episode 20600 reward of Node 2 is 0.4333025371309473
#
# episode 20600 penalty of Node 1 is 0.0
#
# episode 20600 penalty of Node 2 is -0.004935568708081939
#
# episode 20600 transmission discrepancy is [0.0010676413371086824, 4.3916444809610766e-05, 0.032483098950848444, 0.005113958719029199, 0.020231541371998674, 0.004505759115172481, 0.0034197972083482853, 0.004795340946309068]
#
# episode 20800 reward of Node 1 is -0.8619014522948398
#
# episode 20800 reward of Node 2 is 0.42689076695566475
#
# episode 20800 penalty of Node 1 is 0.0
#
# episode 20800 penalty of Node 2 is -1.0957889875699678e-05
#
# episode 20800 transmission discrepancy is [0.0013573655904366433, 0.005760316821124434, 0.03760224268833667, 0.010843439427716817, 0.022229971750824973, 0.01847709844189538, 0.006708179971781192, 0.006600284064880668]
#
# episode 21000 reward of Node 1 is -0.8612905503339601
#
# episode 21000 reward of Node 2 is 0.4295607909294741
#
# episode 21000 penalty of Node 1 is 0.0
#
# episode 21000 penalty of Node 2 is -8.320649002827806e-06
#
# episode 21000 transmission discrepancy is [0.002225554686766884, 0.0043796635630144465, 0.019208993512165762, 0.004070944287953182, 0.021969772423929612, 0.005996197548061133, 0.0010435815041347496, 0.0243117825022523]
#
# episode 21200 reward of Node 1 is -0.8604802017448445
#
# episode 21200 reward of Node 2 is 0.4294708038852189
#
# episode 21200 penalty of Node 1 is 0.0
#
# episode 21200 penalty of Node 2 is -1.210051084192898e-05
#
# episode 21200 transmission discrepancy is [0.00037335340788047233, 0.006016845400793613, 0.03227434266909768, 0.0036809312353724977, 0.025164615565167026, 0.025366197970164706, 0.0035918210831411557, 0.02453700108767265]
#
# episode 21400 reward of Node 1 is -0.8594875477759554
#
# episode 21400 reward of Node 2 is 0.4332259153623363
#
# episode 21400 penalty of Node 1 is 0.0
#
# episode 21400 penalty of Node 2 is -0.02056866347461821
#
# episode 21400 transmission discrepancy is [0.0012869536248700797, 0.0024000968256814303, 0.010325870800244275, 0.004090177830001096, 0.02706714988927672, 0.01405465940829842, 0.006504192506788797, 0.0171421841839674]
#
# episode 21600 reward of Node 1 is -0.8595405093628049
#
# episode 21600 reward of Node 2 is 0.42319539327439704
#
# episode 21600 penalty of Node 1 is 0.0
#
# episode 21600 penalty of Node 2 is -7.224840570783897e-06
#
# episode 21600 transmission discrepancy is [0.0037324097330184713, 0.0031786547534409237, 0.009044511790321508, 0.00247127828555449, 0.0005665820157361168, 0.02615869969069351, 0.0013049122094379584, 0.02579135722963599]
#
# episode 21800 reward of Node 1 is -0.8596115272602595
#
# episode 21800 reward of Node 2 is 0.4214516939521581
#
# episode 21800 penalty of Node 1 is 0.0
#
# episode 21800 penalty of Node 2 is -1.275962745161472e-05
#
# episode 21800 transmission discrepancy is [0.0009496373130346569, 0.0038164454276454762, 0.01406551109792531, 0.006751371708695331, 0.015328563026770325, 0.017173399249461596, 0.01085902530549987, 0.058652321387114625]
#
# episode 22000 reward of Node 1 is -0.8588389823756357
#
# episode 22000 reward of Node 2 is 0.4215537355570927
#
# episode 22000 penalty of Node 1 is 0.0
#
# episode 22000 penalty of Node 2 is -1.880247962394286e-05
#
# episode 22000 transmission discrepancy is [0.0029571825855825296, 0.0037402770359449278, 0.010481878660300481, 0.002950409926803843, 0.010939783403500769, 0.08087882173412808, 0.013130275099769051, 0.0629461677933989]
#
# episode 22200 reward of Node 1 is -0.8577890156544586
#
# episode 22200 reward of Node 2 is 0.4231438673428342
#
# episode 22200 penalty of Node 1 is 0.0
#
# episode 22200 penalty of Node 2 is -1.4553835740854027e-05
#
# episode 22200 transmission discrepancy is [0.020408470822822267, 0.0021730451401538176, 0.024525378116948104, 0.002929225244194811, 0.001071194715862589, 0.012900787962490057, 0.018708459357927865, 0.06282179604814075]
#
# episode 22400 reward of Node 1 is -0.856807129452282
#
# episode 22400 reward of Node 2 is 0.4273028776796033
#
# episode 22400 penalty of Node 1 is 0.0
#
# episode 22400 penalty of Node 2 is -8.11173426352312e-06
#
# episode 22400 transmission discrepancy is [0.00087752965981025, 0.0012490256125801125, 0.005949240181365667, 0.002449153531543402, 0.0025804082233378267, 0.009134652053717218, 0.014298312520814704, 0.044579020852062]
#
# episode 22600 reward of Node 1 is -0.856029891228715
#
# episode 22600 reward of Node 2 is 0.4274204573502695
#
# episode 22600 penalty of Node 1 is 0.0
#
# episode 22600 penalty of Node 2 is -8.105940380082189e-06
#
# ...
#
# episode 93000 reward of Node 1 is -0.8518096692476127
#
# episode 93000 reward of Node 2 is 0.4209568783044612
#
# episode 93000 penalty of Node 1 is 0.0
#
# episode 93000 penalty of Node 2 is -1.2468108742602623e-07
#
# episode 93000 transmission discrepancy is [8.212570678978182e-05, 1.6988271880791217e-05, 4.9510555697906966e-05, 3.415158928987694e-06, 0.00037271728796639536, 8.208969629919238e-05, 0.0003562434661326108, 0.0002837207305645961]
#
# episode 93200 reward of Node 1 is -0.8519471536601699
#
# episode 93200 reward of Node 2 is 0.4209379956675581
#
# episode 93200 penalty of Node 1 is 0.0
#
# episode 93200 penalty of Node 2 is -9.141161998940106e-08
#
# episode 93200 transmission discrepancy is [4.4778590790883754e-07, 5.468758580917665e-05, 3.9478460593045384e-05, 0.00011999049259259209, 0.000417939753333485, 0.00012016569200312688, 1.3292118723029489e-05, 0.0001481143109316463]
#
# episode 93400 reward of Node 1 is -0.8518262474714182
#
# episode 93400 reward of Node 2 is 0.4214148387953185
#
# episode 93400 penalty of Node 1 is 0.0
#
# episode 93400 penalty of Node 2 is -1.0979356290974352e-07
#
# episode 93400 transmission discrepancy is [6.944148908871739e-05, 2.0003178278216183e-05, 2.2860018205506094e-05, 7.584924377823654e-05, 0.00027693090176938995, 3.647047541477377e-05, 7.560957929797496e-05, 0.0005207707432646203]
#
# episode 93600 reward of Node 1 is -0.8516154061137824
#
# episode 93600 reward of Node 2 is 0.42051932702150424
#
# episode 93600 penalty of Node 1 is 0.0
#
# episode 93600 penalty of Node 2 is -1.4145771086333526e-07
#
# episode 93600 transmission discrepancy is [2.5646848975213743e-05, 9.620345818461828e-05, 2.1253266481835453e-05, 7.852398928775983e-05, 0.00020764007030038556, 0.00012174847812929102, 0.00013675695041825975, 0.0007268040468559889]
#
# episode 93800 reward of Node 1 is -0.8515768368569442
#
# episode 93800 reward of Node 2 is 0.4201130012717213
#
# episode 93800 penalty of Node 1 is 0.0
#
# episode 93800 penalty of Node 2 is -1.0438713943230483e-07
#
# episode 93800 transmission discrepancy is [4.0101541486592396e-05, 7.492606027881266e-05, 7.279697996409595e-06, 6.272256634076712e-05, 0.00022029478768104127, 8.428454553310871e-05, 9.009601430065572e-05, 0.00046416618070566074]
#
# episode 94000 reward of Node 1 is -0.8515836450222374
#
# episode 94000 reward of Node 2 is 0.4197039288116997
#
# episode 94000 penalty of Node 1 is 0.0
#
# episode 94000 penalty of Node 2 is -6.797917532743725e-08
#
# episode 94000 transmission discrepancy is [3.0135036354295153e-05, 7.387738018849177e-05, 2.5082938250875486e-05, 9.271738863247947e-05, 0.00028327785343407186, 2.532696702317594e-05, 0.00011161380383839514, 3.776038555258765e-05]
#
# episode 94200 reward of Node 1 is -0.851571314176415
#
# episode 94200 reward of Node 2 is 0.41887706168011135
#
# episode 94200 penalty of Node 1 is 0.0
#
# episode 94200 penalty of Node 2 is -7.500546571961309e-08
#
# episode 94200 transmission discrepancy is [2.617009006655735e-05, 7.298046220682863e-05, 1.5398640300645638e-06, 0.00013312411694954562, 0.0002833387202230142, 5.1951325829691086e-05, 0.00014306708143863034, 3.7882996451799045e-05]
#
# episode 94400 reward of Node 1 is -0.8513997330096925
#
# episode 94400 reward of Node 2 is 0.41832008796739273
#
# episode 94400 penalty of Node 1 is 0.0
#
# episode 94400 penalty of Node 2 is -8.089392480599145e-08
#
# episode 94400 transmission discrepancy is [3.341777080834163e-05, 0.00018072686818015882, 5.312740303509145e-05, 8.061871623965544e-05, 0.00010080420832991877, 0.0001762145219927902, 0.00017599102669407785, 8.03873277988032e-06]
#
# episode 94600 reward of Node 1 is -0.8518913482162976
#
# episode 94600 reward of Node 2 is 0.4182489539211383
#
# episode 94600 penalty of Node 1 is 0.0
#
# episode 94600 penalty of Node 2 is -5.456182479122163e-08
#
# episode 94600 transmission discrepancy is [3.8285928383174905e-05, 3.556603216736676e-05, 6.846459513099035e-06, 0.0001040297681811353, 0.00016451483199375616, 1.353683995830579e-05, 4.615188230161493e-05, 0.00013668650541376337]
#
# episode 94800 reward of Node 1 is -0.8519491787037887
#
# episode 94800 reward of Node 2 is 0.41796810957711406
#
# episode 94800 penalty of Node 1 is 0.0
#
# episode 94800 penalty of Node 2 is -9.598778000743381e-08
#
# episode 94800 transmission discrepancy is [9.356982474173492e-05, 0.00012879964493350826, 9.59982921244773e-06, 7.984280092898643e-05, 7.685321751438323e-05, 7.31337810009336e-05, 0.0001879596087910329, 0.0003101190929513109]
#
# episode 95000 reward of Node 1 is -0.8519424407912315
#
# episode 95000 reward of Node 2 is 0.41823616540689823
#
# episode 95000 penalty of Node 1 is 0.0
#
# episode 95000 penalty of Node 2 is -9.451911007296588e-08
#
# episode 95000 transmission discrepancy is [5.953449772277963e-06, 0.00035306205575125205, 8.152144971518283e-05, 2.2966784634093074e-05, 1.4292310709151934e-05, 7.726054827372764e-05, 5.8902135567251435e-05, 0.0003312323663067218]
#
# episode 95200 reward of Node 1 is -0.852040095604109
#
# episode 95200 reward of Node 2 is 0.41843682145886574
#
# episode 95200 penalty of Node 1 is 0.0
#
# episode 95200 penalty of Node 2 is -6.855718943654665e-08
#
# episode 95200 transmission discrepancy is [1.1862521276384541e-06, 4.755345032236846e-05, 3.565083373757716e-05, 2.2622494981305863e-05, 0.00015398039895586635, 5.330221193133866e-05, 2.2745798609946632e-05, 0.0003485304536994249]
#
# episode 95400 reward of Node 1 is -0.8522410390618979
#
# episode 95400 reward of Node 2 is 0.418806158628217
#
# episode 95400 penalty of Node 1 is 0.0
#
# episode 95400 penalty of Node 2 is -5.73682251513219e-08
#
# episode 95400 transmission discrepancy is [2.2175739751162382e-05, 3.3829813048669166e-05, 4.102125004123991e-06, 6.084546523510426e-05, 0.0002097407673034013, 0.0001566988700112404, 7.369433287962579e-05, 1.2595138279891671e-05]
#
# episode 95600 reward of Node 1 is -0.8521937911851782
#
# episode 95600 reward of Node 2 is 0.41903908336893075
#
# episode 95600 penalty of Node 1 is 0.0
#
# episode 95600 penalty of Node 2 is -7.510595305149083e-08
#
# episode 95600 transmission discrepancy is [1.6918660698195254e-05, 2.0102253316167662e-05, 1.7400732900796356e-05, 5.609590598254499e-05, 0.0001790890799568956, 0.0001800863426879573, 6.44345669158497e-05, 0.00021693198805650127]
#
# episode 95800 reward of Node 1 is -0.8520273073379536
#
# episode 95800 reward of Node 2 is 0.4193653634748633
#
# episode 95800 penalty of Node 1 is 0.0
#
# episode 95800 penalty of Node 2 is -1.5534460560182595e-07
#
# episode 95800 transmission discrepancy is [8.591239513577875e-06, 2.7112735835999047e-05, 6.091816885600565e-06, 6.86948186867653e-05, 0.00023882647110440303, 0.0006322209116795818, 0.00015045415040049193, 0.0004214539119118399]
#
# episode 96000 reward of Node 1 is -0.8520861354767184
#
# episode 96000 reward of Node 2 is 0.42011268158386167
#
# episode 96000 penalty of Node 1 is 0.0
#
# episode 96000 penalty of Node 2 is -9.63832065878023e-08
#
# episode 96000 transmission discrepancy is [9.427216411950212e-07, 3.4589294656939273e-05, 7.247183049230443e-07, 3.09906352526923e-05, 0.00012325629318610254, 0.00037908498464389595, 0.000111474076824436, 0.00028276934136783893]
#
# episode 96200 reward of Node 1 is -0.8521044648598829
#
# episode 96200 reward of Node 2 is 0.4203634727483634
#
# episode 96200 penalty of Node 1 is 0.0
#
# episode 96200 penalty of Node 2 is -7.399683675579638e-08
#
# episode 96200 transmission discrepancy is [1.1031229973923473e-07, 3.900246060339896e-05, 1.2771232860586679e-05, 9.414089142012472e-05, 0.00023187652421796656, 0.00020267660353567862, 6.952532528359257e-05, 8.986501733687646e-05]
#
# episode 96400 reward of Node 1 is -0.8521056681330291
#
# episode 96400 reward of Node 2 is 0.420604744275562
#
# episode 96400 penalty of Node 1 is 0.0
#
# episode 96400 penalty of Node 2 is -9.166805082223561e-08
#
# episode 96400 transmission discrepancy is [2.614615226548267e-06, 3.9227578866984913e-05, 1.82641073394052e-05, 7.216531290765715e-05, 0.00024136328639201565, 0.0003123543063310308, 7.12676679270885e-06, 0.00022356453436600532]
#
# episode 96600 reward of Node 1 is -0.8520524292281806
#
# episode 96600 reward of Node 2 is 0.42087305261173
#
# episode 96600 penalty of Node 1 is 0.0
#
# episode 96600 penalty of Node 2 is -9.97510893832043e-08
#
# episode 96600 transmission discrepancy is [2.6304960769607533e-06, 6.780869628641994e-05, 8.642387541613061e-06, 0.00013902098745433022, 0.0002536035306945905, 0.000256513243996892, 1.791601903278206e-05, 0.0002513755327484546]
#
# episode 96800 reward of Node 1 is -0.8521683522755796
#
# episode 96800 reward of Node 2 is 0.4209142274982346
#
# episode 96800 penalty of Node 1 is 0.0
#
# episode 96800 penalty of Node 2 is -8.456042954847476e-08
#
# episode 96800 transmission discrepancy is [4.197506413561314e-07, 3.010598479136206e-05, 1.747038436406001e-05, 0.00011777928238387858, 0.00021820069039790724, 0.00033269985618744613, 3.770105333700258e-05, 9.122729338173485e-05]
#
# episode 97000 reward of Node 1 is -0.8521713271781555
#
# episode 97000 reward of Node 2 is 0.4208709908985241
#
# episode 97000 penalty of Node 1 is 0.0
#
# episode 97000 penalty of Node 2 is -8.920956323841266e-08
#
# episode 97000 transmission discrepancy is [9.085232619554517e-07, 4.128120740176655e-05, 3.552970704845393e-05, 0.00010724595017563843, 0.0002753205015437743, 0.0001728265473168733, 9.950683319459586e-05, 0.00015947636244106889]
#
# episode 97200 reward of Node 1 is -0.8523328572750744
#
# episode 97200 reward of Node 2 is 0.4209359034369195
#
# episode 97200 penalty of Node 1 is 0.0
#
# episode 97200 penalty of Node 2 is -6.806077165570912e-08
#
# episode 97200 transmission discrepancy is [1.1960947006173228e-06, 4.2662705745044605e-05, 4.2794450564542785e-05, 0.0001564719643454282, 0.0002778219073462651, 9.073891710897897e-05, 1.2060093776966596e-05, 5.686158296924759e-05]
#
# episode 97400 reward of Node 1 is -0.8522787473469315
#
# episode 97400 reward of Node 2 is 0.4209276325451423
#
# episode 97400 penalty of Node 1 is 0.0
#
# episode 97400 penalty of Node 2 is -7.247879583687223e-08
#
# episode 97400 transmission discrepancy is [2.011730124706901e-06, 3.903343354494382e-05, 3.047405201073161e-05, 0.00015735140988226703, 0.00021166854420329173, 0.00010168278848610157, 4.326697456846773e-05, 0.00013929902554821183]
#
# episode 97600 reward of Node 1 is -0.8522305325929725
#
# episode 97600 reward of Node 2 is 0.4209968834206468
#
# episode 97600 penalty of Node 1 is 0.0
#
# episode 97600 penalty of Node 2 is -7.181021163447099e-08
#
# episode 97600 transmission discrepancy is [2.788175947898708e-07, 4.51549150000119e-05, 1.750250225995842e-05, 0.00014618825389334233, 0.0002090902051889998, 0.00013792935406442552, 9.149120829121671e-05, 7.046686005196534e-05]
#
# episode 97800 reward of Node 1 is -0.8521858793212853
#
# episode 97800 reward of Node 2 is 0.42099270243687226
#
# episode 97800 penalty of Node 1 is 0.0
#
# episode 97800 penalty of Node 2 is -5.981348151529176e-08
#
# episode 97800 transmission discrepancy is [3.051042092749867e-06, 5.1060655366086394e-05, 1.676486060375737e-05, 7.657075381217737e-05, 0.0002312410508906737, 0.00019146597795938192, 1.1609762992748074e-05, 1.6370711435342855e-05]
#
# episode 98000 reward of Node 1 is -0.8521613052152532
#
# episode 98000 reward of Node 2 is 0.42101446140692145
#
# episode 98000 penalty of Node 1 is 0.0
#
# episode 98000 penalty of Node 2 is -7.622841104577561e-08
#
# episode 98000 transmission discrepancy is [1.511157371680838e-06, 4.442488058487015e-05, 2.5006052553067093e-05, 0.0001026435265387704, 0.00026387043831732626, 0.00016340496797795367, 2.1033767517053548e-05, 0.00014038931959703405]
#
# episode 98200 reward of Node 1 is -0.8521211337815291
#
# episode 98200 reward of Node 2 is 0.4210505284873269
#
# episode 98200 penalty of Node 1 is 0.0
#
# episode 98200 penalty of Node 2 is -6.926824319570812e-08
#
# episode 98200 transmission discrepancy is [1.2241446682992319e-06, 3.399711108897918e-05, 2.0410460336961478e-05, 0.00013148736265122807, 0.00025034134564094757, 0.00022815692901545503, 1.4294364532929649e-05, 1.2770714022281027e-05]
#
# episode 98400 reward of Node 1 is -0.8520919635463114
#
# episode 98400 reward of Node 2 is 0.42105953166551635
#
# episode 98400 penalty of Node 1 is 0.0
#
# episode 98400 penalty of Node 2 is -6.160810392259463e-08
#
# episode 98400 transmission discrepancy is [1.8217943775766798e-06, 4.909463329738628e-05, 1.810784173983393e-05, 0.00011310027525723854, 0.000241695869434011, 8.876642743160801e-05, 7.406453661928936e-05, 2.9429661069002577e-05]
#
# episode 98600 reward of Node 1 is -0.8521349204267268
#
# episode 98600 reward of Node 2 is 0.42090609513414234
#
# episode 98600 penalty of Node 1 is 0.0
#
# episode 98600 penalty of Node 2 is -7.422358388389227e-08
#
# episode 98600 transmission discrepancy is [7.952587566251168e-08, 3.220833978900828e-05, 2.5354009636657793e-05, 0.00011888458270448155, 0.00027925052371102765, 8.117354743575333e-05, 9.666613532743895e-06, 0.00019561869615358773]
#
# episode 98800 reward of Node 1 is -0.8521543197455099
#
# episode 98800 reward of Node 2 is 0.42040488270468596
#
# episode 98800 penalty of Node 1 is 0.0
#
# episode 98800 penalty of Node 2 is -5.66601158851654e-08
#
# episode 98800 transmission discrepancy is [5.968558980384842e-11, 3.06603400801464e-05, 2.845487718161621e-05, 0.00012018429833915434, 0.00022436777304335465, 0.0001155342532790371, 2.71605617250259e-05, 2.0238995517729563e-05]
#
# episode 99000 reward of Node 1 is -0.8520635616709719
#
# episode 99000 reward of Node 2 is 0.42046010761879143
#
# episode 99000 penalty of Node 1 is 0.0
#
# episode 99000 penalty of Node 2 is -4.291787246764046e-08
#
# episode 99000 transmission discrepancy is [3.695543142612223e-06, 5.156817684337511e-05, 4.073682617899976e-06, 9.96610827570521e-05, 0.0001847708996365327, 5.3627760610908126e-05, 4.541756084108783e-06, 2.7239822983915474e-05]
#
# episode 99200 reward of Node 1 is -0.8520322938134587
#
# episode 99200 reward of Node 2 is 0.4208173355055979
#
# episode 99200 penalty of Node 1 is 0.0
#
# episode 99200 penalty of Node 2 is -4.554734681931905e-08
#
# episode 99200 transmission discrepancy is [1.5999377183106844e-06, 3.344585221043417e-05, 8.9329716672637e-06, 0.0001025492739472611, 0.0002172498750496743, 6.274678870710204e-05, 6.111749108583808e-06, 2.2837019784560653e-05]
#
# episode 99400 reward of Node 1 is -0.8519792769945107
#
# episode 99400 reward of Node 2 is 0.42097151057096227
#
# episode 99400 penalty of Node 1 is 0.0
#
# episode 99400 penalty of Node 2 is -8.003775723857133e-08
#
# episode 99400 transmission discrepancy is [1.6564487118841953e-05, 4.109310808075861e-05, 2.446486389828806e-05, 0.00013376379442320285, 0.00026469507084669885, 3.540417485936587e-05, 3.1698917663192105e-05, 0.00025269315549536486]
#
# episode 99600 reward of Node 1 is -0.8519833098469785
#
# episode 99600 reward of Node 2 is 0.42108415095084883
#
# episode 99600 penalty of Node 1 is 0.0
#
# episode 99600 penalty of Node 2 is -1.0995972223390993e-07
#
# episode 99600 transmission discrepancy is [5.970922956066715e-07, 2.1166024112062587e-05, 1.693703923422163e-05, 0.0001056243189694328, 0.00022881406781749547, 6.36200576771273e-05, 6.212401681437996e-05, 0.0006007146054187729]
#
# episode 99800 reward of Node 1 is -0.8520772610564312
#
# episode 99800 reward of Node 2 is 0.42091814444093767
#
# episode 99800 penalty of Node 1 is 0.0
#
# episode 99800 penalty of Node 2 is -7.223901524788801e-08
#
# episode 99800 transmission discrepancy is [2.471335577070022e-06, 2.8796395021402077e-05, 2.8193116833108434e-05, 0.00013915479494386318, 0.00025452532657510574, 0.0001893526674621171, 4.356478214262438e-05, 3.633173392358913e-05]
#
# episode 100000 reward of Node 1 is -0.8518511254205375
#
# episode 100000 reward of Node 2 is 0.42103376634055234
#
# episode 100000 penalty of Node 1 is 0.0
#
# episode 100000 penalty of Node 2 is -6.258454620251542e-08
#
# episode 100000 transmission discrepancy is [7.4604660227350905e-06, 3.324389923164972e-05, 2.094792192508521e-05, 0.00010042902121654151, 0.00028509667595244537, 2.4736051102536294e-05, 7.80654451162377e-05, 7.586598145792323e-05]

# %%
env.mc
# Out:
# array([ -8.01032416,  -9.2399429 ,  -7.76521021,  -9.55300566,
#        -10.25278069, -12.44073187, -11.05108533,  -8.46050024])

# %%
env.trans
# Out:
# array([61.51250259, 62.71230452, 74.21667482, 58.46730814, 33.76750102,
#        30.14791235, 29.64798301, 32.12608197])

# %%
print('final raward {}'.format(-0.8518511254205375 + 0.42103376634055234))
# Out:
# final raward -0.4308173590799852
